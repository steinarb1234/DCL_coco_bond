# %% [markdown]
# ## DCL CoCo Bonds
#
# The following code imports data exported from Reuters, then uses it to model DCL CoCo bonds.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import configparser as cp
import warnings

# Ignore Eikon python library deprecation warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# ------------------- Load data from Reuters -------------------

def load_reuters_data(ticker_ric, data_folder = "data") -> pd.DataFrame: 
    """
    Load timeseries data from Reuters
    """

    close_df              = pd.read_excel(f'{data_folder}/{ticker_ric}/Close.xlsx', index_col = 0, parse_dates = True)
    shares_outstanding_df = pd.read_excel(f'{data_folder}/{ticker_ric}/TR.IssueSharesOutstanding.xlsx', index_col = 0, parse_dates = True)
    market_cap_df         = pd.read_excel(f'{data_folder}/{ticker_ric}/TR.CompanyMarketCapitalization.xlsx', index_col = 0, parse_dates = True)
    total_assets_df       = pd.read_excel(f'{data_folder}/{ticker_ric}/TR.TotalAssets.xlsx', index_col = 0, parse_dates = True)
    total_debt_df         = pd.read_excel(f'{data_folder}/{ticker_ric}/TR.TotalDebtOutstanding.xlsx', index_col = 0, parse_dates = True)
    # at1_debt_df           = pd.read_excel(f'{data_folder}/cs_at1_debt.xlsx', index_col = 0, parse_dates = True)

    # Drop duplicates
    # TODO: see if we can not do this in the first place
    close_df              = close_df[~close_df.index.duplicated(keep='first')]
    shares_outstanding_df = shares_outstanding_df[~shares_outstanding_df.index.duplicated(keep='first')]
    market_cap_df         = market_cap_df[~market_cap_df.index.duplicated(keep='first')]
    total_assets_df       = total_assets_df[~total_assets_df.index.duplicated(keep='first')]
    total_debt_df         = total_debt_df[~total_debt_df.index.duplicated(keep='first')]
    # at1_debt_df           = at1_debt_df[~at1_debt_df.index.duplicated(keep='first')]

    # Fill days inbetween with the last available value
    start_date = close_df.index.min()
    end_date = close_df.index.max()
    full_range = pd.date_range(
        start=start_date - pd.DateOffset(years=1),
        end=end_date,
    )
    close_df = close_df.reindex(full_range).ffill()
    shares_outstanding_df = shares_outstanding_df.reindex(full_range).ffill()
    market_cap_df = market_cap_df.reindex(full_range).ffill()
    total_assets_df = total_assets_df.reindex(full_range).ffill()
    total_debt_df = total_debt_df.reindex(full_range).ffill()
    # at1_debt_df = at1_debt_df.reindex(full_range).ffill()

    # Remove non-business days
    full_range = pd.date_range(
        start=start_date,
        end=end_date,
        freq='B'
    )
    close_df = close_df.reindex(full_range)
    shares_outstanding_df = shares_outstanding_df.reindex(full_range)
    market_cap_df = market_cap_df.reindex(full_range)
    total_assets_df = total_assets_df.reindex(full_range)
    total_debt_df = total_debt_df.reindex(full_range)
    # at1_debt_df = at1_debt_df.reindex(full_range)

    input_data = close_df.merge(shares_outstanding_df, left_index=True, right_index=True, how='left')
    input_data = input_data.merge(market_cap_df, left_index=True, right_index=True, how='left')
    input_data = input_data.merge(total_assets_df, left_index=True, right_index=True, how='left')
    input_data = input_data.merge(total_debt_df, left_index=True, right_index=True, how='left')
    # input_data = input_data.merge(at1_debt_df, left_index=True, right_index=True, how='left')

    input_data["Equity Value"] = input_data["Close"] * input_data["Issue Default Shares Outstanding"]

    return input_data


def generate_inputs_monte_carlo(
    T=10, dt=1/252,  # 10 years, daily frequency
    mu=-0.15, sigma=0.25,  # Annual drift and volatility
    initial_equity=60e9, initial_price=21.69, initial_debt=275e9,
    seed=42
) -> pd.DataFrame:
    """
    Generate synthetic Monte Carlo financial data for a hypothetical firm.
    
    Parameters:
    - T: Time horizon in years
    - dt: Time step (e.g., 1/252 for daily)
    - mu: Expected annual return of equity
    - sigma: Volatility of equity
    - initial_equity: Starting equity value
    - initial_debt: Starting total debt
    - seed: Random seed for reproducibility
    
    Returns:
    - DataFrame indexed by date with synthetic financial data
    """
    np.random.seed(seed)
    N = int(T / dt)
    dates = pd.bdate_range(start="2025-01-01", periods=N)

    # 1) Determine constant shares outstanding so that S0 * N_shares = initial_equity
    N_shares = initial_equity / initial_price

    # 2) Simulate GBM for the stock price
    price = np.zeros(N)
    price[0] = initial_price

    drift = (mu - 0.5 * sigma**2) * dt
    vol   = sigma * np.sqrt(dt)

    for t in range(1, N):
        z = np.random.normal()
        price[t] = price[t-1] * np.exp(drift + vol * z)

    # 3) Build the DataFrame
    equity      = price * N_shares
    market_cap  = equity
    total_debt  = np.full(N, initial_debt)
    total_assets = equity + total_debt

    input_data = pd.DataFrame({
        "Close": price,
        "Issue Default Shares Outstanding": N_shares,
        "Company Market Capitalization": market_cap,
        "TR.TotalAssets": total_assets,
        "Total Debt": total_debt,
        "Equity Value": equity
    }, index=dates)

    return input_data




class DCL_Bond:
    def __init__(self, name, ticker_ric, Q_init, L_min, L_c, S_p, r, T_years = 10, freq = 1, L_min_breach_response = "issue new debt", monte_carlo_random_seed = 42):

        self.name = name
        
        # Load ticker data exported from Reuters Eikon
        self.ticker_ric = ticker_ric
        
        # Get company data
        if ticker_ric == 'Monte Carlo':
            print("Processing Monte carlo simulation number", monte_carlo_random_seed)
            self.input_data = generate_inputs_monte_carlo(seed=monte_carlo_random_seed)
        else:
            self.input_data = load_reuters_data(ticker_ric)

        # Initialize the results dataframe
        self.dcl_data = self.input_data.copy()
        self.dcl_data["Market cap / Share price"] = self.dcl_data["Company Market Capitalization"] / self.dcl_data["Close"]
        
        self.Q_init = Q_init # Initial nominal value of the DCL bond
        self.L_min = L_min   # Min leverage ratio trigger
        self.L_c = L_c       # Max leverage ratio trigger
        
        # Set conversion price
        if S_p == "initial share price": # Sets the first close price in the time series as S_p
            self.S_p = self.dcl_data['Close'][0]
        elif type(S_p) == int or type(S_p) == float: # We don't accept np.float as input
            self.S_p = S_p
        else:
            raise ValueError
        
        self.r = r
        self.T_years = T_years
        self.freq = freq

        self.L_min_breach_response = L_min_breach_response # Can be "issue new debt" or "issue new debt and do share buybacks"

        self.results = self.simulate_DCL()

    def calculate_residual_value_of_dcl(self, Q, r, T_years, k_years):
        """
        Calculate the residual value of DCL bond at time k. 
        """

        return Q * ((1 + r)**k_years + (1 - (1 + r)**k_years)/(1 - (1 + r)**(-T_years)))

    def calculate_alpha(self, RQ_k, total_debt):
        """
        Calculate the ratio of CoCos to total debt. 
        """
        
        return RQ_k / total_debt

    def calculate_leverage_ratio(self, RQ_k, NS_k_1, S_k, alpha_k):
        """
        Calculate the leverage ratio. 
        """

        return RQ_k / (RQ_k + alpha_k * NS_k_1 * S_k)

    def compute_period_index(self, dates):
        """
        Given a DatetimeIndex, returns two arrays:
        - period_array: which 'period' you are in 
        - k_array: how many 'periods' have passed since the start
        
        """
        if self.freq == 365: # Daily
            # Number of days since the start date
            base = dates[0]
            day_counts = (dates - base).days
            return day_counts, day_counts  # (period, k) are effectively the same
        
        elif self.freq == 12: # Monthly
            # A convenient measure: year*12 + month
            base_year  = dates[0].year
            base_month = dates[0].month
            
            period_array = (dates.year - base_year) * 12 + (dates.month - base_month)
            return period_array, period_array
        
        elif self.freq == 2: # Bi-annual
            # Count how many 6-month periods have passed since the start
            base_year = dates[0].year
            base_month = dates[0].month
            base_half_year = (base_month - 1) // 6  # 0 for Jan-Jun, 1 for Jul-Dec
            
            period_array = (dates.year - base_year) * 2 + ((dates.month - 1) // 6) - base_half_year
            return period_array, period_array
        
        elif self.freq == 1: # yearly
            base_year = dates[0].year
            year_offset = (dates.year - base_year)
            return year_offset, year_offset
        
        elif self.freq == 0: # No DCL (no rebalancing)
            return np.zeros(len(dates)), np.zeros(len(dates))
        
        else:
            raise ValueError(f"Invalid frequency '{self.freq}'.")


    def simulate_DCL(self):
        """
        Simulate the DCL model. 
        """

        period_array, k_array = self.compute_period_index(dates = self.dcl_data.index)
        # print(period_array)
        # print(k_array)
        self.dcl_data['period'] = period_array
        # self.dcl_data['k'] = self.dcl_data.index.year - self.dcl_data.index.year[0]
        self.dcl_data['k']      = k_array

        # Conversion constant for period number to year
        if self.freq == 0:
            period_to_years = 99999
        else:
            period_to_years = 1 / self.freq
        
        # -------------- Set initial values for the DCL bond ------------------
        # self.dcl_data['Book value of debt'] = self.dcl_data['Total Debt']
        # self.dcl_data['Shares outstanding'] = self.dcl_data['Common Shares - Outstanding - Total']
        # self.dcl_data['Shares outstanding'] = self.dcl_data['Issue Default Shares Outstanding'][0]
        self.dcl_data['Shares outstanding'] = self.dcl_data['Issue Default Shares Outstanding']
        self.dcl_data['Q']                  = self.Q_init
        self.dcl_data['Top up loan']        = 0.0
        self.dcl_data['New shares issued']  = 0.0
        self.dcl_data['RQ_k']               = np.nan
        self.dcl_data['alpha_k']              = np.nan
        # self.dcl_data['Leverage ratio']     = np.nan
        self.dcl_data['Payment size'] = 0

        # ------------------ Simulate for each day ------------------
        all_dates = self.dcl_data.index
        for idx, day in enumerate(all_dates):
            # Compute the fraction of a year that has elapsed for this k
            k_in_years = self.dcl_data.loc[day, 'k'] * period_to_years

            if idx != 0:
                # By default, carry forward the nominal Q from prior day
                previous_day = self.dcl_data.index[idx - 1]
                self.dcl_data.loc[day, 'Q'] = self.dcl_data.loc[previous_day, 'Q']

            self.dcl_data.loc[day, 'RQ_k'] = self.calculate_residual_value_of_dcl( # Compute the residual value of DCL
                self.dcl_data.loc[day, 'Q'], 
                self.r, 
                self.T_years, 
                k_in_years,
            )
            self.dcl_data.loc[day, 'alpha_k'] = self.calculate_alpha( # Compute alpha_k (the proportion of DCL to total debt)
                self.dcl_data.loc[day, 'RQ_k'], 
                self.dcl_data.loc[day, 'Total Debt']
            )
            self.dcl_data.loc[day, 'Leverage ratio'] = self.calculate_leverage_ratio( # Compute the leverage ratio
                self.dcl_data.loc[day, 'RQ_k'], 
                self.dcl_data.loc[day, 'Shares outstanding'], 
                self.dcl_data.loc[day, 'Close'],
                self.dcl_data.loc[day, 'alpha_k'],
            )

            # On the very first day, we just fill RQ_k but do no payments / rebalancing
            if idx == 0:
                continue


            # We only rebalance once per "period" change under freq.
            # For example, if freq=12, this triggers once a new month starts.
            if self.dcl_data.loc[day, 'period'] != self.dcl_data.loc[previous_day, 'period']: # Payment date reached

                if self.freq != 0:
                    delta_T = ((self.dcl_data.loc[day, 'k'] - self.dcl_data.loc[previous_day, 'k']) * period_to_years)

                    # self.dcl_data.loc[day, 'Payment size'] = self.r * self.dcl_data.loc[day, 'Q'] / (1 - (1 + self.r)**(-self.T_years * self.freq))
                    # self.dcl_data.loc[day, 'Payment size'] = self.r * self.dcl_data.loc[day, 'Q'] / (1 - (1 + self.r)**(-self.T_years))

                    # See Appendix B in the DCL paper for the following formula:
                    self.dcl_data.loc[day, 'Payment size'] = (self.dcl_data.loc[previous_day, 'RQ_k'] * (1 + self.r) ** delta_T) - self.dcl_data.loc[day, 'RQ_k']
                
                # Calculate the leverage ratio to see if we have to adjust with new shares or new debt
                L_k = self.dcl_data.loc[day, 'Leverage ratio']

                if L_k < self.L_min: # Leverage ratio is below minimum
                    # print(f"{day} - Leverage ratio is below minimum: L_k = {L_k}")

                    if self.L_min_breach_response == "issue new debt":

                        # In this case, issue new debt to raise the leverage ratio
                        # self.dcl_data.loc[day, 'Top up loan'] = -self.dcl_data.loc[day, 'RQ_k'] + self.L_min * self.dcl_data.loc[day, 'Shares outstanding'] * self.dcl_data.loc[day, 'Close'] / (1 - self.L_min)
                        self.dcl_data.loc[day, 'Top up loan'] = -self.dcl_data.loc[day, 'Total Debt'] + self.L_min * self.dcl_data.loc[day, 'Shares outstanding'] * self.dcl_data.loc[day, 'Close'] / (1 - self.L_min)
                        self.dcl_data.loc[day:, 'Q'] += self.dcl_data.loc[day, 'Top up loan'] # Nominal of the DCL
                        self.dcl_data.loc[day:, 'Total Debt'] += self.dcl_data.loc[day, 'Top up loan'] # Total debt of the company

                    elif self.L_min_breach_response == "issue new debt and do share buybacks":
                        # In this case, issue new debt to raise the leverage ratio and do share buybacks
                        self.dcl_data.loc[day, 'Top up loan'] = -self.dcl_data.loc[day, 'RQ_k'] + self.L_min * self.dcl_data.loc[day, 'Shares outstanding'] * self.dcl_data.loc[day, 'Close'] / (1 - self.L_min)
                        self.dcl_data.loc[day:, 'Q'] += self.dcl_data.loc[day, 'Top up loan']
                        self.dcl_data.loc[day:, 'Total Debt'] += self.dcl_data.loc[day, 'Top up loan'] # Total debt of the company
                        # TODO: Finish this part

                    else: raise ValueError(f'Invalid response to L_min breach "{self.L_min_breach_response}", possible responses are "issue new debt" or "issue new debt and do share buybacks".')

                    # recompute residual value, alpha_k and leverage ratio with the new numbers
                    self.dcl_data.loc[day, 'RQ_k'] = self.calculate_residual_value_of_dcl(
                        self.dcl_data.loc[day, 'Q'], 
                        self.r, 
                        self.T_years, 
                        k_in_years,
                    )
                    self.dcl_data.loc[day, 'alpha_k'] = self.calculate_alpha(
                        self.dcl_data.loc[day, 'RQ_k'], self.dcl_data.loc[day, 'Total Debt']
                    )
                    self.dcl_data.loc[day, 'Leverage ratio'] = self.calculate_leverage_ratio(
                        self.dcl_data.loc[day, 'RQ_k'],
                        self.dcl_data.loc[day, 'Shares outstanding'],
                        self.dcl_data.loc[day, 'Close'],
                        self.dcl_data.loc[day, 'alpha_k'],
                    )

                elif L_k > self.L_c: # Leverage ratio is above critical level
                    
                    # In this case, convert DCL interest payments to new shares instead
                    # print(f"{day} - Leverage ratio is above critical: L_k = {L_k}")

                    # New shares issued for converting the interest payment to shares
                    shares_issued = self.dcl_data.loc[day, 'Payment size'] / self.S_p

                    # New shares issued to make the leverage ratio be exactly at L_c
                    shares_issued_to_L_c = self.dcl_data.loc[day, 'RQ_k'] * (1 - self.L_c) / (self.L_c * self.dcl_data.loc[day, 'alpha_k'] * self.dcl_data.loc[day, 'Close']) - self.dcl_data.loc[day, 'Shares outstanding']
                    
                    # We don't convert beyond the leverage ratio
                    if shares_issued > shares_issued_to_L_c: 
                        shares_issued = shares_issued_to_L_c 

                    # print(f"{day} - New shares issued: {self.dcl_data.loc[day, 'New shares issued']}")
                    if shares_issued > 0:
                        self.dcl_data.loc[day:, 'Shares outstanding'] = self.dcl_data.loc[day:, 'Shares outstanding'] + shares_issued

                    self.dcl_data.loc[day, 'New shares issued'] = shares_issued # Document additional shares issued

                if k_in_years >= self.T_years:
                    print(f"Final k in years for freq {self.freq}: ", k_in_years)
                    break




        self.dcl_data.to_excel(f'data/{self.ticker_ric}/Results - frequency {self.freq}.xlsx')
        return self.dcl_data
    
    def plot_input_data(self):
        """
        Plot the stock data. 
        """

        fig, ax = plt.subplots(4, 1, sharex=True, figsize=(10, 12))
        fig.suptitle("Input data from Refinitv Eikon", fontsize=14)
        self.dcl_data["Close"].plot(ax=ax[0])
        ax[0].set_title("Share price (Daily Close)") 
        self.dcl_data["Issue Default Shares Outstanding"].plot(ax=ax[1])
        ax[1].set_title("Historical shares outstanding")
        # ax[2].set_title("Market cap / Share price")
        # self.dcl_data["Market cap / Share price"].plot(ax=ax[2])
        self.dcl_data["Equity Value"].plot(ax=ax[2])
        ax[2].set_title("Equity Value")
        self.dcl_data["Total Debt"].plot(ax=ax[3])
        ax[3].set_title("Total Debt")

        plt.tight_layout()
        plt.savefig(f"images/input_data.png")
        plt.show()



# =========================================================================
#                              Simulations
# =========================================================================

# --------------------------  Credit Suisse -------------------------------

cs_r = 0.075
cs_Q_init = 10_216_000_000 # Initial nominal value of DCL bonds -> Set as initial AT1 debt value
# cs_L_min = 0
# cs_L_min = 0.80
cs_L_min = 0.85
# cs_L_c   = 1
cs_L_c   = 0.9

cs_dcl_daily = DCL_Bond(
    name       = "Credit Suisse - Daily",
    ticker_ric = "CSGN.S^F23",          # Reuters Intrument Code (RIC) for the ticker
    Q_init     = cs_Q_init,             # Initial value of DCL bonds
    L_min      = cs_L_min,              # Minimum leverage ratio
    L_c        = cs_L_c,                # Critical leverage ratio
    S_p        = "initial share price", # Conversion price
    r          = cs_r,                  # Risk free rate TODO: change to timeseries?
    T_years    = 10,                    # Number of years to maturity for DCL bonds
    freq       = 365,                   # Frequency of interest payments and leverage considerations
)

cs_dcl_monthly = DCL_Bond(
    name       = "Credit Suisse - Monthly",
    ticker_ric = "CSGN.S^F23",          # Reuters Intrument Code (RIC) for the ticker
    Q_init     = cs_Q_init,             # Initial value of DCL bonds
    L_min      = cs_L_min,              # Minimum leverage ratio
    L_c        = cs_L_c,                # Critical leverage ratio
    S_p        = "initial share price", # Conversion price
    r          = cs_r,                  # Risk free rate TODO: change to timeseries?
    T_years    = 10,                    # Number of years to maturity for DCL bonds
    freq       = 12,             # Frequency of interest payments and leverage considerations
)

cs_dcl_biannual = DCL_Bond(
    name       = "Credit Suisse - Bi-annual",
    ticker_ric = "CSGN.S^F23",          # Reuters Intrument Code (RIC) for the ticker
    Q_init     = cs_Q_init,             # Initial value of DCL bonds
    L_min      = cs_L_min,              # Minimum leverage ratio
    L_c        = cs_L_c,                # Critical leverage ratio
    S_p        = "initial share price", # Conversion price
    r          = cs_r,                  # Risk free rate TODO: change to timeseries?
    T_years    = 10,                    # Number of years to maturity for DCL bonds
    freq       = 2,            # Frequency of interest payments and leverage considerations
)

cs_dcl_yearly = DCL_Bond(
    name       = "Credit Suisse - Yearly",
    ticker_ric = "CSGN.S^F23",          # Reuters Intrument Code (RIC) for the ticker
    Q_init     = cs_Q_init,             # Initial value of DCL bonds
    L_min      = cs_L_min,              # Minimum leverage ratio
    L_c        = cs_L_c,                # Critical leverage ratio
    S_p        = "initial share price", # Conversion price
    r          = cs_r,                  # Risk free rate TODO: change to timeseries?
    T_years    = 10,                    # Number of years to maturity for DCL bonds
    freq       = 1,              # Frequency of interest payments and leverage considerations
)

# No DCL bond, freq = 0
cs_no_dcl = DCL_Bond(
    name       = "Credit Suisse - No DCL",
    ticker_ric = "CSGN.S^F23",          # Reuters Intrument Code (RIC) for the ticker
    Q_init     = 1,                     # Initial value of DCL bonds
    L_min      = cs_L_min,              # Minimum leverage ratio
    L_c        = cs_L_c,                # Critical leverage ratio
    S_p        = "initial share price", # Conversion price
    r          = cs_r,                  # Risk free rate TODO: change to timeseries?
    T_years    = 10,                    # Number of years to maturity for DCL bonds
    freq       = 0,         # Frequency of interest payments and leverage considerations
)

# cs_dcl_yearly.reuters_input_data
cs_dcl_yearly.results
# Out:
#                 Close  Issue Default Shares Outstanding  \
# 2015-01-05  21.686784                      1.607169e+09
# 2015-01-06  21.313945                      1.607169e+09
# 2015-01-07  21.216297                      1.607169e+09
# 2015-01-08  21.509242                      1.607169e+09
# 2015-01-09  20.967738                      1.607169e+09
# ...               ...                               ...
# 2023-06-06   0.809600                      4.002158e+09
# 2023-06-07   0.810200                      4.002158e+09
# 2023-06-08   0.811000                      4.002158e+09
# 2023-06-09   0.808000                      4.002158e+09
# 2023-06-12   0.817000                      4.002158e+09
#
#             Company Market Capitalization  Total Assets    Total Debt  \
# 2015-01-05                   4.148007e+10  9.214620e+11  3.007920e+11
# 2015-01-06                   4.076694e+10  9.214620e+11  3.007920e+11
# 2015-01-07                   4.058017e+10  9.214620e+11  3.007920e+11
# 2015-01-08                   4.114049e+10  9.214620e+11  3.007920e+11
# 2015-01-09                   4.010476e+10  9.214620e+11  3.007920e+11
# ...                                   ...           ...           ...
# 2023-06-06                   3.240147e+09  5.313580e+11  1.929070e+11
# 2023-06-07                   3.242548e+09  5.313580e+11  1.929070e+11
# 2023-06-08                   3.245750e+09  5.313580e+11  1.929070e+11
# 2023-06-09                   3.233744e+09  5.313580e+11  1.929070e+11
# 2023-06-12                   3.269763e+09  5.313580e+11  1.929070e+11
#
#             Equity Value  Market cap / Share price  period  k  \
# 2015-01-05  3.485433e+10              1.912689e+09       0  0
# 2015-01-06  3.425511e+10              1.912689e+09       0  0
# 2015-01-07  3.409817e+10              1.912689e+09       0  0
# 2015-01-08  3.456899e+10              1.912689e+09       0  0
# 2015-01-09  3.369870e+10              1.912689e+09       0  0
# ...                  ...                       ...     ... ..
# 2023-06-06  3.240147e+09              4.002158e+09       8  8
# 2023-06-07  3.242548e+09              4.002158e+09       8  8
# 2023-06-08  3.245750e+09              4.002158e+09       8  8
# 2023-06-09  3.233744e+09              4.002158e+09       8  8
# 2023-06-12  3.269763e+09              4.002158e+09       8  8
#
#             Shares outstanding            Q  Top up loan  New shares issued  \
# 2015-01-05        1.607169e+09  10216000000          0.0                0.0
# 2015-01-06        1.607169e+09  10216000000          0.0                0.0
# 2015-01-07        1.607169e+09  10216000000          0.0                0.0
# 2015-01-08        1.607169e+09  10216000000          0.0                0.0
# 2015-01-09        1.607169e+09  10216000000          0.0                0.0
# ...                        ...          ...          ...                ...
# 2023-06-06        4.288332e+09  10216000000          0.0                0.0
# 2023-06-07        4.288332e+09  10216000000          0.0                0.0
# 2023-06-08        4.288332e+09  10216000000          0.0                0.0
# 2023-06-09        4.288332e+09  10216000000          0.0                0.0
# 2023-06-12        4.288332e+09  10216000000          0.0                0.0
#
#                     RQ_k   alpha_k  Payment size  Leverage ratio
# 2015-01-05  1.021600e+10  0.033964           0.0        0.896158
# 2015-01-06  1.021600e+10  0.033964           0.0        0.897760
# 2015-01-07  1.021600e+10  0.033964           0.0        0.898181
# 2015-01-08  1.021600e+10  0.033964           0.0        0.896920
# 2015-01-09  1.021600e+10  0.033964           0.0        0.899254
# ...                  ...       ...           ...             ...
# 2023-06-06  2.672389e+09  0.013853           0.0        0.982321
# 2023-06-07  2.672389e+09  0.013853           0.0        0.982308
# 2023-06-08  2.672389e+09  0.013853           0.0        0.982291
# 2023-06-09  2.672389e+09  0.013853           0.0        0.982355
# 2023-06-12  2.672389e+09  0.013853           0.0        0.982162
#
# [2201 rows x 17 columns]

# %%
# --------------------- Plot the input data ---------------------

cs_dcl_yearly.plot_input_data()

# %% [markdown]
# $RQ_k = Q * ((1 + r)^k + (1 - (1 + r)^k)/(1 - (1 + r)^{-N_m}))$ (only applies if the triggers are not breached)
#
# $L_k = \text{Total debt} / (\text{Total equity} + \text{Total debt}) = RQ_k / (RQ_k + NS_{k-1} * S_k)$
#
# $\alpha = RQ_k / (RQ_k + \text{Book value of non CoCo debt})$

# %%
# ------------------------ Plot the results -------------------------

def plot_results(no_dcl_bond: DCL_Bond, dcl_bond: DCL_Bond, title: str) -> None:
    """
    Plot the results. 
    """

    fig, ax = plt.subplots(5, 1, sharex=True, figsize=(10,16))
    fig.suptitle(title, fontsize=14)
    i = 0

    # # ------------------------------------------------------------------
    # # 1) Stock price
    # # ------------------------------------------------------------------
    # ax[0].plot(dcl_bond.dcl_data.index, dcl_bond.dcl_data['Close'], label='Close')
    # ax[0].set_title('Stock Price')
    # ax[0].legend(loc='best')
    # i += 1

    # ------------------------------------------------------------------
    # Equity value
    # ------------------------------------------------------------------
    # TODO: Veriffy that Company Market Capitalization is correct, it seems to give a larger value than the close * shares outstanding, even at the starting date
    # ax[i].plot(dcl_bond.dcl_data.index, dcl_bond.dcl_data['Company Market Capitalization'], label='Historical equity value')
    # ax[i].plot(dcl_bond.dcl_data.index, dcl_bond.dcl_data['Company Market Capitalization'], label='Historical equity value')
    ax[i].plot(dcl_bond.results.index, dcl_bond.results['Close']*dcl_bond.results['Issue Default Shares Outstanding'], label='Historical equity value')
    ax[i].plot(dcl_bond.results.index, dcl_bond.results['Close']*dcl_bond.results['Shares outstanding'], label='Equity value with DCL')
    ax[i].set_title('Equity Value')
    ax[i].legend(loc='best')
    i += 1

    # TODO: Add shares outstanding plot
    # ax[1].plot(df.index, df['Shares outstanding'], label='Shares outstanding')
    # ax[1].set_title('Shares outstanding')

    # ------------------------------------------------------------------
    # 2) Leverage ratio
    # ------------------------------------------------------------------

    ax[i].plot(no_dcl_bond.results.index, no_dcl_bond.results['Leverage ratio'], label='Leverage without DCL')
    ax[i].plot(dcl_bond.results.index, dcl_bond.results['Leverage ratio'], label='Leverage with DCL')
    if dcl_bond.L_min != 0:
        ax[i].axhline(y=dcl_bond.L_min, linestyle='--', label='L_min', color='red')
    if dcl_bond.L_c != 1:
        ax[i].axhline(y=dcl_bond.L_c,   linestyle='--', label='L_c',   color='green')
    # ax[i].set_ylim(dcl_bond.L_min - 0.01, 1)
    # ax[i].set_ylim(0.875, 1)
    ax[i].set_title('Leverage Comparison: No DCL vs. With DCL')
    ax[i].legend(loc='best')
    i += 1

    # ------------------------------------------------------------------
    # 3) Residual value of DCL bond
    # ------------------------------------------------------------------
    ax[i].plot(dcl_bond.results.index, dcl_bond.results['RQ_k'], label='RQ_k')
    ax[i].set_title('Residual Value of DCL Bond')
    # ax[1].legend(loc='best')
    i += 1

    # TODO: Add alpha plot
    # TODO: Add new debt issued plot

    # ------------------------------------------------------------------
    # 4) New Debt Issued
    # ------------------------------------------------------------------
    if dcl_bond.results['Top up loan'].sum() > 0:
        ax[i].bar(dcl_bond.results.index, dcl_bond.results['Top up loan'], label='Top up loan', width=10)
    else:
        ax[i].text(0.5, 0.5, '[No top up loans]', ha='center', va='center', transform=ax[i].transAxes)
    ax[i].set_title('Top up loans')
    i += 1

    # ------------------------------------------------------------------
    # 5) New Shares Issued
    # ------------------------------------------------------------------
    if dcl_bond.results['New shares issued'].sum() > 0:
        ax[i].bar(dcl_bond.results.index, dcl_bond.results['New shares issued'], label='New Shares Issued', width=10)
    else:
        ax[i].text(0.5, 0.5, 'No new shares issued', ha='center', va='center', transform=ax[i].transAxes)
    ax[i].set_title('New Shares Issued')
    i += 1

    # ------------------------------------------------------------------
    # Add vertical lines at the start of each period k
    # ------------------------------------------------------------------
    if dcl_bond.freq <= 52: # Clearer to not have vertical lines for daily intervals
        for k_val in dcl_bond.results['k'].unique():
            # For that k_val, find the first time index (i.e., the earliest date) 
            # in the DataFrame where k == k_val
            first_date_k = dcl_bond.results[dcl_bond.results['k'] == k_val].index[0]
            
            # You can choose on which subplot(s) you want the lines.
            # If you want the line in all subplots, iterate over `ax`. 
            # If you want it only in the last subplot, do just ax[2].axvline(...).
            for axis in ax:
                axis.axvline(first_date_k, color='gray', linestyle='--', alpha=0.5)

    plt.tight_layout()
    plt.savefig(f"images/{title}.png")
    plt.show()


# plot_results(cs_no_dcl, cs_dcl_yearly, title="Credit Suisse - Yearly Interval DCL Bond")
plot_results(cs_no_dcl, cs_dcl_biannual, title="Credit Suisse - Biannual Interval DCL Bond")
plot_results(cs_no_dcl, cs_dcl_monthly, title="Credit Suisse - Monthly Interval DCL Bond")
plot_results(cs_no_dcl, cs_dcl_daily, title="Credit Suisse - Daily Interval DCL Bond")

# %%
# Calculate the book value leverage ratio and compare with DCL values

# %%
# Compare leverage ratios for different parameters
def plot_leverage_ratios(dcl_bonds: list[DCL_Bond], title: str, interv_lines = False, L_c_lines = True) -> None:
    """
    Plot the leverage ratios. 
    """

    fig, ax = plt.subplots(1, 1, sharex=True, figsize=(10,6))
    fig.suptitle(title, fontsize=14)

    for dcl_bond in dcl_bonds:
        ax.plot(dcl_bond.results.index, dcl_bond.results['Leverage ratio'], label=f"{dcl_bond.name}")
    if L_c_lines:
        ax.axhline(y=dcl_bond.L_min, linestyle='--', color='red')
        ax.axhline(y=dcl_bond.L_c,   linestyle='--',   color='green')
    if interv_lines:
        for k_val in dcl_bond.results['k'].unique():
            first_date_k = dcl_bond.results[dcl_bond.results['k'] == k_val].index[0]
            ax.axvline(first_date_k, color='gray', linestyle='--', alpha=0.5)
    ax.set_title('Leverage Ratio')
    ax.legend(loc='best')
    plt.tight_layout()
    plt.savefig(f"images/{title}.png")
    plt.show()


# Compare levarage ratios for different frequencies
plot_leverage_ratios([
    cs_no_dcl, 
    cs_dcl_yearly, 
    cs_dcl_biannual, 
    cs_dcl_monthly, 
    # cs_dcl_daily
    ], 
    title="Credit Suisse - Leverage Ratios for Different Frequencies of Payments and Adjustments",
)

# %%
# Compare different conversion prices, S_p

cs_dcl_conversion_prices = [
    DCL_Bond(
        name       = f"Credit Suisse - S_p = {db_S_p}",
        ticker_ric = "CSGN.S^F23",          # Reuters Intrument Code (RIC) for the ticker
        Q_init     = cs_Q_init,             # Initial value of DCL bonds
        L_min      = cs_L_min,              # Minimum leverage ratio
        L_c        = cs_L_c,                # Critical leverage ratio
        S_p        = db_S_p,                    # Conversion price
        r          = cs_r,                  # Risk free rate TODO: change to timeseries?
        T_years    = 10,                    # Number of years to maturity for DCL bonds
        freq       = 2,              # Frequency of interest payments and leverage considerations
    ) for db_S_p in [40, 20, 10, 5]
]
cs_dcl_conversion_prices.insert(0, cs_no_dcl)

# %%
# Plot the leverages different conversion prices
plot_leverage_ratios(cs_dcl_conversion_prices, title="Credit Suisse - Leverage Ratios for Different Conversion Prices", interv_lines = True)

# %%
# Compare different Q_init values
cs_dcl_initial_nominals = [
    DCL_Bond(
        name       = f"Credit Suisse - Q_init = {db_Q_init:,.0f}",
        ticker_ric = "CSGN.S^F23",          # Reuters Intrument Code (RIC) for the ticker
        Q_init     = db_Q_init,             # Initial value of DCL bonds
        L_min      = cs_L_min,              # Minimum leverage ratio
        L_c        = cs_L_c,                # Critical leverage ratio
        S_p        = "initial share price", # Conversion price
        r          = cs_r,                  # Risk free rate TODO: change to timeseries?
        T_years    = 10,                    # Number of years to maturity for DCL bonds
        freq       = 2,              # Frequency of interest payments and leverage considerations
    ) for db_Q_init in [1_000_000_000, 10_000_000_000, 50_000_000_000, 100_000_000_000, 300_000_000_000]
]
cs_dcl_initial_nominals.insert(0, cs_no_dcl)

plot_leverage_ratios(cs_dcl_initial_nominals, title="Credit Suisse - Leverage Ratios for Different Initial Nominal Values", interv_lines = True)

# %%
# Compare different L_c values

cs_dcl_leverage_ratios = [
    DCL_Bond(
        name       = f"Credit Suisse - L_c = {db_L_c}",
        ticker_ric = "CSGN.S^F23",          # Reuters Intrument Code (RIC) for the ticker
        Q_init     = cs_Q_init,             # Initial value of DCL bonds
        L_min      = cs_L_min,              # Minimum leverage ratio
        L_c        = db_L_c,                # Critical leverage ratio
        S_p        = "initial share price", # Conversion price
        r          = cs_r,                  # Risk free rate TODO: change to timeseries?
        T_years    = 10,                    # Number of years to maturity for DCL bonds
        freq       = 2,              # Frequency of interest payments and leverage considerations
    ) for db_L_c in [0.94, 0.92, 0.9, 0.88]
]
cs_dcl_leverage_ratios.insert(0, cs_no_dcl)

# %%
# Plot the leverage for different L_c values

plot_leverage_ratios(cs_dcl_leverage_ratios, title="Credit Suisse - Leverage for Different Critical Ratios", interv_lines = True, L_c_lines = False)

# %%
# --------------------------  Deutsche Bank -------------------------------

db_r = 0.075

# https://investor-relations.db.com/files/documents/annual-reports/Annual_Financial_Statements_and_Management_Report_Deutsche_Bank_AG_2014.pdf?language_id=1#:~:text=The%20bank%20maintained%20its%20stable,end%202014
db_Q_init = 4_619_000_000 # Total AT1 debt for Deutsche Bank in 31 December 2024

db_L_min = 0.85
db_L_c   = 0.9

db_dcl_biannual = DCL_Bond(
    name       = "Deutsche Bank - DCL",
    ticker_ric = "DBKGn.DE",          # Reuters Intrument Code (RIC) for the ticker
    Q_init     = db_Q_init,             # Initial value of DCL bonds
    L_min      = db_L_min,              # Minimum leverage ratio
    L_c        = db_L_c,                # Critical leverage ratio
    S_p        = "initial share price", # Conversion price
    r          = db_r,                  # Risk free rate TODO: change to timeseries?
    T_years    = 10,                    # Number of years to maturity for DCL bonds
    freq       = 2,              # Frequency of interest payments and leverage considerations
)

db_no_dcl = DCL_Bond(
    name       = "Deutsche Bank - No DCL",
    ticker_ric = "DBKGn.DE",          # Reuters Intrument Code (RIC) for the ticker
    Q_init     = 1,                     # Initial value of DCL bonds
    L_min      = db_L_min,              # Minimum leverage ratio
    L_c        = db_L_c,                # Critical leverage ratio
    S_p        = "initial share price", # Conversion price
    r          = db_r,                  # Risk free rate TODO: change to timeseries?
    T_years    = 10,                    # Number of years to maturity for DCL bonds
    freq       = 0,         # Frequency of interest payments and leverage considerations
)


plot_results(db_no_dcl, db_dcl_biannual, title="Deutsche Bank - Biannual Interval DCL Bond")

# %%
# --------------------------  Silicon Valley Bank -------------------------------

sv_r = 0.075
sv_Q_init = 10_216_000_000 # TODO: find Initial value of DCL bonds -> Set to initial AT1 debt value
sv_L_min = 0.85
sv_L_c   = 0.9

sv_dcl_biannual = DCL_Bond(
    name       = "Silicon Valley Bank - DCL",
    ticker_ric = "SIVBQ.PK^K24",          # Reuters Intrument Code (RIC) for the ticker
    Q_init     = sv_Q_init,             # Initial value of DCL bonds
    L_min      = sv_L_min,              # Minimum leverage ratio
    L_c        = sv_L_c,                # Critical leverage ratio
    S_p        = "initial share price", # Conversion price
    r          = sv_r,                  # Risk free rate TODO: change to timeseries?
    T_years    = 10,                    # Number of years to maturity for DCL bonds
    freq       = 2,              # Frequency of interest payments and leverage considerations
)

sv_no_dcl = DCL_Bond(
    name       = "Silicon Valley Bank - No DCL",
    ticker_ric = "SIVBQ.PK^K24",          # Reuters Intrument Code (RIC) for the ticker
    Q_init     = 1,                     # Initial value of DCL bonds
    L_min      = sv_L_min,              # Minimum leverage ratio
    L_c        = sv_L_c,                # Critical leverage ratio
    S_p        = "initial share price", # Conversion price
    r          = sv_r,                  # Risk free rate TODO: change to timeseries?
    T_years    = 10,                    # Number of years to maturity for DCL bonds
    freq       = 0,         # Frequency of interest payments and leverage considerations
)

plot_results(sv_no_dcl, sv_dcl_biannual, title="Silicon Valley Bank - Biannual Interval DCL Bond")

# %%
# --------------------------  Lehman Brothers -------------------------------

le_r = 0.05
le_Q_init = 10_216_000_000 # TODO: find Initial value of DCL bonds -> Set to initial AT1 debt value
le_L_min = 0.85
le_L_c   = 0.9

le_dcl_biannual = DCL_Bond(
    name       = "Lehman Brothers - DCL",
    ticker_ric = "LEHMQ.PK^C12",          # Reuters Intrument Code (RIC) for the ticker
    Q_init     = le_Q_init,             # Initial value of DCL bonds
    L_min      = le_L_min,              # Minimum leverage ratio
    L_c        = le_L_c,                # Critical leverage ratio
    S_p        = "initial share price", # Conversion price
    r          = le_r,                  # Risk free rate TODO: change to timeseries?
    T_years    = 10,                    # Number of years to maturity for DCL bonds
    freq       = 2,              # Frequency of interest payments and leverage considerations
)

le_no_dcl = DCL_Bond(
    name       = "SLehman Brothers- No DCL",
    ticker_ric = "LEHMQ.PK^C12",          # Reuters Intrument Code (RIC) for the ticker
    Q_init     = 1,                     # Initial value of DCL bonds
    L_min      = le_L_min,              # Minimum leverage ratio
    L_c        = le_L_c,                # Critical leverage ratio
    S_p        = "initial share price", # Conversion price
    r          = le_r,                  # Risk free rate TODO: change to timeseries?
    T_years    = 10,                    # Number of years to maturity for DCL bonds
    freq       = 0,         # Frequency of interest payments and leverage considerations
)

plot_results(le_no_dcl, le_dcl_biannual, title="Lehman Brothers - Biannual Interval DCL Bond")

# %%
# Calculate total value of dilutions for new shares issued

def calculate_total_dilution(dcl_bond: DCL_Bond):
    # print(dcl_bond.S_p)
    dilutions = dcl_bond.results['New shares issued'] * dcl_bond.results['Close']
    total = dilutions.sum()
    print(f"    {dcl_bond.name}: {total:>15,.0f} CHF")
    # print(f"{total:,.0f}")

print("Total dilution from share issuances of DCL bonds - Credit Suisse: ")
calculate_total_dilution(cs_dcl_daily)
calculate_total_dilution(cs_dcl_monthly)
calculate_total_dilution(cs_dcl_biannual)
calculate_total_dilution(cs_dcl_yearly)
print("Total dilution from share issuances of DCL bonds - Deutsche Bank:")
calculate_total_dilution(db_dcl_biannual)

print("Dilutions for different S_p values")
for dcl_bond in cs_dcl_conversion_prices:
    calculate_total_dilution(dcl_bond)

print("Diltuions for different L_c values")
for dcl_bond in cs_dcl_leverage_ratios:
    calculate_total_dilution(dcl_bond)


print("Dilutions for different initial nominals")
for dcl_bond in cs_dcl_initial_nominals:
    calculate_total_dilution(dcl_bond)
# Out:
# Total dilution from share issuances of DCL bonds - Credit Suisse:
#     Credit Suisse - Daily:   2,558,630,056 CHF
#     Credit Suisse - Monthly:   2,561,445,587 CHF
#     Credit Suisse - Bi-annual:   2,445,032,848 CHF
#     Credit Suisse - Yearly:   2,555,453,474 CHF
# Total dilution from share issuances of DCL bonds - Deutsche Bank:
#     Deutsche Bank - DCL:   1,344,386,331 CHF
# Dilutions for different S_p values
#     Credit Suisse - No DCL:               0 CHF
#     Credit Suisse - S_p = 40:   1,440,862,600 CHF
#     Credit Suisse - S_p = 20:   2,582,021,019 CHF
#     Credit Suisse - S_p = 10:   4,227,971,795 CHF
#     Credit Suisse - S_p = 5:   5,379,393,217 CHF
# Diltuions for different L_c values
#     Credit Suisse - No DCL:               0 CHF
#     Credit Suisse - L_c = 0.94:     266,117,457 CHF
#     Credit Suisse - L_c = 0.92:     590,169,920 CHF
#     Credit Suisse - L_c = 0.9:   2,445,032,848 CHF
#     Credit Suisse - L_c = 0.88:   4,284,133,873 CHF
# Dilutions for different initial nominals
#     Credit Suisse - No DCL:               0 CHF
#     Credit Suisse - Q_init = 1,000,000,000:     260,139,632 CHF
#     Credit Suisse - Q_init = 10,000,000,000:   2,410,690,779 CHF
#     Credit Suisse - Q_init = 50,000,000,000:   5,455,826,836 CHF
#     Credit Suisse - Q_init = 100,000,000,000:   7,740,773,567 CHF
#     Credit Suisse - Q_init = 300,000,000,000:  21,713,380,713 CHF

# %%
# Time gained for different L_c values compared to no DCL scenario

def calculate_time_gained(dcl_bond: DCL_Bond, no_dcl_bond: DCL_Bond) -> float:
    """
    Calculate the time gained for different L_c values compared to no DCL scenario.
    """

    # Get the last k value for the DCL bond
    dcl_k = dcl_bond.results['k'].max()
    
    # Get the last k value for the no DCL bond
    no_dcl_k = no_dcl_bond.results['k'].max()

    return (dcl_k - no_dcl_k) * dcl_bond.freq

def calculate_time_gained_all(dcl_bonds: list[DCL_Bond], no_dcl_bond: DCL_Bond) -> None:
    """
    Calculate the time gained for different L_c values compared to no DCL scenario.
    """

    print("Time gained for different L_c values compared to no DCL scenario:")
    for dcl_bond in dcl_bonds:
        time_gained = calculate_time_gained(dcl_bond, no_dcl_bond)
        print(f"    {dcl_bond.name}: {time_gained:.2f} years")
        # print(f"    {dcl_bond.name}: {time_gained:.2f} years ({time_gained * 365:.0f} days)")
        # print(f"    {dcl_bond.name}: {time_gained:.2f} years ({time_gained * 365 * 24:.0f} hours)")
        # print(f"    {dcl_bond.name}: {time_gained:.2f} years ({time_gained * 365 * 24 * 60:.0f} minutes)")
        # print(f"    {dcl_bond.name}: {time_gained:.2f} years ({time_gained * 365 * 24 * 60 * 60:.0f} seconds)")

    print("Total time gained for different L_c values compared to no DCL scenario:")
    total_time_gained = sum([calculate_time_gained(dcl_bond, no_dcl_bond) for dcl_bond in dcl_bonds])
    print(f"    {total_time_gained:.2f} years")

number_of_simulations = 2000

monte_carlo_dcls = [
    [
        # No DCL
        DCL_Bond(
            name       = "Credit Suisse - No DCL",
            ticker_ric = "Monte Carlo",          # Reuters Intrument Code (RIC) for the ticker
            monte_carlo_random_seed = i,   
            Q_init     = 1,                     # Initial value of DCL bonds
            L_min      = cs_L_min,              # Minimum leverage ratio
            L_c        = cs_L_c,                # Critical leverage ratio
            S_p        = "initial share price", # Conversion price
            r          = cs_r,                  # Risk free rate TODO: change to timeseries?
            T_years    = 10,                    # Number of years to maturity for DCL bonds
            freq       = 0,         # Frequency of interest payments and leverage considerations
        ),

        # With DCL
        DCL_Bond(
            name       = "Monte Carlo - Bi-annual",
            ticker_ric = "Monte Carlo",          # Reuters Intrument Code (RIC) for the ticker
            monte_carlo_random_seed = i,        
            Q_init     = cs_Q_init,             # Initial value of DCL bonds
            L_min      = cs_L_min,              # Minimum leverage ratio
            L_c        = cs_L_c,                # Critical leverage ratio
            S_p        = "initial share price", # Conversion price
            r          = cs_r,                  # Risk free rate TODO: change to timeseries?
            T_years    = 10,                    # Number of years to maturity for DCL bonds
            freq       = 2,            # Frequency of interest payments and leverage considerations
        )
    ] 
    for i in range(number_of_simulations)
]

# Plot the results for one Monte Carlo simulation
plot_results(monte_carlo_dcls[0][0], monte_carlo_dcls[0][1], "Monte carlo")

time_gained = calculate_time_gained(cs_dcl_biannual, cs_no_dcl)

print(time_gained)
# Out:
# Processing Monte carlo simulation number 0
# Processing Monte carlo simulation number 0
# Processing Monte carlo simulation number 1
# Processing Monte carlo simulation number 1
# Processing Monte carlo simulation number 2
# Processing Monte carlo simulation number 2
# Processing Monte carlo simulation number 3
# Processing Monte carlo simulation number 3
# Processing Monte carlo simulation number 4
# Processing Monte carlo simulation number 4
# Processing Monte carlo simulation number 5
# Processing Monte carlo simulation number 5
# Processing Monte carlo simulation number 6
# Processing Monte carlo simulation number 6
# Processing Monte carlo simulation number 7
# Processing Monte carlo simulation number 7
# Processing Monte carlo simulation number 8
# Processing Monte carlo simulation number 8
# Processing Monte carlo simulation number 9
# Processing Monte carlo simulation number 9
# Processing Monte carlo simulation number 10
# Processing Monte carlo simulation number 10
# Processing Monte carlo simulation number 11
# Processing Monte carlo simulation number 11
# Processing Monte carlo simulation number 12
# Processing Monte carlo simulation number 12
# Processing Monte carlo simulation number 13
# Processing Monte carlo simulation number 13
# Processing Monte carlo simulation number 14
# Processing Monte carlo simulation number 14
# Processing Monte carlo simulation number 15
# Processing Monte carlo simulation number 15
# Processing Monte carlo simulation number 16
# Processing Monte carlo simulation number 16
# Processing Monte carlo simulation number 17
# Processing Monte carlo simulation number 17
# Processing Monte carlo simulation number 18
# Processing Monte carlo simulation number 18
# Processing Monte carlo simulation number 19
# Processing Monte carlo simulation number 19
# Processing Monte carlo simulation number 20
# Processing Monte carlo simulation number 20
# Processing Monte carlo simulation number 21
# Processing Monte carlo simulation number 21
# Processing Monte carlo simulation number 22
# Processing Monte carlo simulation number 22
# Processing Monte carlo simulation number 23
# Processing Monte carlo simulation number 23
# Processing Monte carlo simulation number 24
# Processing Monte carlo simulation number 24
# Processing Monte carlo simulation number 25
# Processing Monte carlo simulation number 25
# Processing Monte carlo simulation number 26
# Processing Monte carlo simulation number 26
# Processing Monte carlo simulation number 27
# Processing Monte carlo simulation number 27
# Processing Monte carlo simulation number 28
# Processing Monte carlo simulation number 28
# Processing Monte carlo simulation number 29
# Processing Monte carlo simulation number 29
# Processing Monte carlo simulation number 30
# Processing Monte carlo simulation number 30
# Processing Monte carlo simulation number 31
# Processing Monte carlo simulation number 31
# Processing Monte carlo simulation number 32
# Processing Monte carlo simulation number 32
# Processing Monte carlo simulation number 33
# Processing Monte carlo simulation number 33
# Processing Monte carlo simulation number 34
# Processing Monte carlo simulation number 34
# Processing Monte carlo simulation number 35
# Processing Monte carlo simulation number 35
# Processing Monte carlo simulation number 36
# Processing Monte carlo simulation number 36
# Processing Monte carlo simulation number 37
# Processing Monte carlo simulation number 37
# Processing Monte carlo simulation number 38
# Processing Monte carlo simulation number 38
# Processing Monte carlo simulation number 39
# Processing Monte carlo simulation number 39
# Processing Monte carlo simulation number 40
# Processing Monte carlo simulation number 40
# Processing Monte carlo simulation number 41
# Processing Monte carlo simulation number 41
# Processing Monte carlo simulation number 42
# Processing Monte carlo simulation number 42
# Processing Monte carlo simulation number 43
# Processing Monte carlo simulation number 43
# Processing Monte carlo simulation number 44
# Processing Monte carlo simulation number 44
# Processing Monte carlo simulation number 45
# Processing Monte carlo simulation number 45
# Processing Monte carlo simulation number 46
# Processing Monte carlo simulation number 46
# Processing Monte carlo simulation number 47
# Processing Monte carlo simulation number 47
# Processing Monte carlo simulation number 48
# Processing Monte carlo simulation number 48
# Processing Monte carlo simulation number 49
# Processing Monte carlo simulation number 49
# Processing Monte carlo simulation number 50
# Processing Monte carlo simulation number 50
# Processing Monte carlo simulation number 51
# Processing Monte carlo simulation number 51
# Processing Monte carlo simulation number 52
# Processing Monte carlo simulation number 52
# Processing Monte carlo simulation number 53
# Processing Monte carlo simulation number 53
# Processing Monte carlo simulation number 54
# Processing Monte carlo simulation number 54
# Processing Monte carlo simulation number 55
# Processing Monte carlo simulation number 55
# Processing Monte carlo simulation number 56
# Processing Monte carlo simulation number 56
# Processing Monte carlo simulation number 57
# Processing Monte carlo simulation number 57
# Processing Monte carlo simulation number 58
# Processing Monte carlo simulation number 58
# Processing Monte carlo simulation number 59
# Processing Monte carlo simulation number 59
# Processing Monte carlo simulation number 60
# Processing Monte carlo simulation number 60
# Processing Monte carlo simulation number 61
# Processing Monte carlo simulation number 61
# Processing Monte carlo simulation number 62
# Processing Monte carlo simulation number 62
# Processing Monte carlo simulation number 63
# Processing Monte carlo simulation number 63
# Processing Monte carlo simulation number 64
# Processing Monte carlo simulation number 64
# Processing Monte carlo simulation number 65
# Processing Monte carlo simulation number 65
# Processing Monte carlo simulation number 66
# Processing Monte carlo simulation number 66
# Processing Monte carlo simulation number 67
# Processing Monte carlo simulation number 67
# Processing Monte carlo simulation number 68
# Processing Monte carlo simulation number 68
# Processing Monte carlo simulation number 69
# Processing Monte carlo simulation number 69
# Processing Monte carlo simulation number 70
# Processing Monte carlo simulation number 70
# Processing Monte carlo simulation number 71
# Processing Monte carlo simulation number 71
# Processing Monte carlo simulation number 72
# Processing Monte carlo simulation number 72
# Processing Monte carlo simulation number 73
# Processing Monte carlo simulation number 73
# Processing Monte carlo simulation number 74
# Processing Monte carlo simulation number 74
# Processing Monte carlo simulation number 75
# Processing Monte carlo simulation number 75
# Processing Monte carlo simulation number 76
# Processing Monte carlo simulation number 76
# Processing Monte carlo simulation number 77
# Processing Monte carlo simulation number 77
# Processing Monte carlo simulation number 78
# Processing Monte carlo simulation number 78
# Processing Monte carlo simulation number 79
# Processing Monte carlo simulation number 79
# Processing Monte carlo simulation number 80
# Processing Monte carlo simulation number 80
# Processing Monte carlo simulation number 81
# Processing Monte carlo simulation number 81
# Processing Monte carlo simulation number 82
# Processing Monte carlo simulation number 82
# Processing Monte carlo simulation number 83
# Processing Monte carlo simulation number 83
# Processing Monte carlo simulation number 84
# Processing Monte carlo simulation number 84
# Processing Monte carlo simulation number 85
# Processing Monte carlo simulation number 85
# Processing Monte carlo simulation number 86
# Processing Monte carlo simulation number 86
# Processing Monte carlo simulation number 87
# Processing Monte carlo simulation number 87
# Processing Monte carlo simulation number 88
# Processing Monte carlo simulation number 88
# Processing Monte carlo simulation number 89
# Processing Monte carlo simulation number 89
# Processing Monte carlo simulation number 90
# Processing Monte carlo simulation number 90
# Processing Monte carlo simulation number 91
# Processing Monte carlo simulation number 91
# Processing Monte carlo simulation number 92
# Processing Monte carlo simulation number 92
# Processing Monte carlo simulation number 93
# Processing Monte carlo simulation number 93
# Processing Monte carlo simulation number 94
# Processing Monte carlo simulation number 94
# Processing Monte carlo simulation number 95
# Processing Monte carlo simulation number 95
# Processing Monte carlo simulation number 96
# Processing Monte carlo simulation number 96
# Processing Monte carlo simulation number 97
# Processing Monte carlo simulation number 97
# Processing Monte carlo simulation number 98
# Processing Monte carlo simulation number 98
# Processing Monte carlo simulation number 99
# Processing Monte carlo simulation number 99
# Processing Monte carlo simulation number 100
# Processing Monte carlo simulation number 100
# Processing Monte carlo simulation number 101
# Processing Monte carlo simulation number 101
# Processing Monte carlo simulation number 102
# Processing Monte carlo simulation number 102
# Processing Monte carlo simulation number 103
# Processing Monte carlo simulation number 103
# Processing Monte carlo simulation number 104
# Processing Monte carlo simulation number 104
# Processing Monte carlo simulation number 105
# Processing Monte carlo simulation number 105
# Processing Monte carlo simulation number 106
# Processing Monte carlo simulation number 106
# Processing Monte carlo simulation number 107
# Processing Monte carlo simulation number 107
# Processing Monte carlo simulation number 108
# Processing Monte carlo simulation number 108
# Processing Monte carlo simulation number 109
# Processing Monte carlo simulation number 109
# Processing Monte carlo simulation number 110
# Processing Monte carlo simulation number 110
# Processing Monte carlo simulation number 111
# Processing Monte carlo simulation number 111
# Processing Monte carlo simulation number 112
# Processing Monte carlo simulation number 112
# Processing Monte carlo simulation number 113
# Processing Monte carlo simulation number 113
# Processing Monte carlo simulation number 114
# Processing Monte carlo simulation number 114
# Processing Monte carlo simulation number 115
# Processing Monte carlo simulation number 115
# Processing Monte carlo simulation number 116
# Processing Monte carlo simulation number 116
# Processing Monte carlo simulation number 117
# Processing Monte carlo simulation number 117
# Processing Monte carlo simulation number 118
# Processing Monte carlo simulation number 118
# Processing Monte carlo simulation number 119
# Processing Monte carlo simulation number 119
# Processing Monte carlo simulation number 120
# Processing Monte carlo simulation number 120
# Processing Monte carlo simulation number 121
# Processing Monte carlo simulation number 121
# Processing Monte carlo simulation number 122
# Processing Monte carlo simulation number 122
# Processing Monte carlo simulation number 123
# Processing Monte carlo simulation number 123
# Processing Monte carlo simulation number 124
# Processing Monte carlo simulation number 124
# Processing Monte carlo simulation number 125
# Processing Monte carlo simulation number 125
# Processing Monte carlo simulation number 126
# Processing Monte carlo simulation number 126
# Processing Monte carlo simulation number 127
# Processing Monte carlo simulation number 127
# Processing Monte carlo simulation number 128
# Processing Monte carlo simulation number 128
# Processing Monte carlo simulation number 129
# Processing Monte carlo simulation number 129
# Processing Monte carlo simulation number 130
# Processing Monte carlo simulation number 130
# Processing Monte carlo simulation number 131
# Processing Monte carlo simulation number 131
# Processing Monte carlo simulation number 132
# Processing Monte carlo simulation number 132
# Processing Monte carlo simulation number 133
# Processing Monte carlo simulation number 133
# Processing Monte carlo simulation number 134
# Processing Monte carlo simulation number 134
# Processing Monte carlo simulation number 135
# Processing Monte carlo simulation number 135
# Processing Monte carlo simulation number 136
# Processing Monte carlo simulation number 136
# Processing Monte carlo simulation number 137
# Processing Monte carlo simulation number 137
# Processing Monte carlo simulation number 138
# Processing Monte carlo simulation number 138
# Processing Monte carlo simulation number 139
# Processing Monte carlo simulation number 139
# Processing Monte carlo simulation number 140
# Processing Monte carlo simulation number 140
# Processing Monte carlo simulation number 141
# Processing Monte carlo simulation number 141
# Processing Monte carlo simulation number 142
# Processing Monte carlo simulation number 142
# Processing Monte carlo simulation number 143
# Processing Monte carlo simulation number 143
# Processing Monte carlo simulation number 144
# Processing Monte carlo simulation number 144
# Processing Monte carlo simulation number 145
# Processing Monte carlo simulation number 145
# Processing Monte carlo simulation number 146
# Processing Monte carlo simulation number 146
# Processing Monte carlo simulation number 147
# Processing Monte carlo simulation number 147
# Processing Monte carlo simulation number 148
# Processing Monte carlo simulation number 148
# Processing Monte carlo simulation number 149
# Processing Monte carlo simulation number 149
# Processing Monte carlo simulation number 150
# Processing Monte carlo simulation number 150
# Processing Monte carlo simulation number 151
# Processing Monte carlo simulation number 151
# Processing Monte carlo simulation number 152
# Processing Monte carlo simulation number 152
# Processing Monte carlo simulation number 153
# Processing Monte carlo simulation number 153
# Processing Monte carlo simulation number 154
# Processing Monte carlo simulation number 154
# Processing Monte carlo simulation number 155
# Processing Monte carlo simulation number 155
# Processing Monte carlo simulation number 156
# Processing Monte carlo simulation number 156
# Processing Monte carlo simulation number 157
# Processing Monte carlo simulation number 157
# Processing Monte carlo simulation number 158
# Processing Monte carlo simulation number 158
# Processing Monte carlo simulation number 159
# Processing Monte carlo simulation number 159
# Processing Monte carlo simulation number 160
# Processing Monte carlo simulation number 160
# Processing Monte carlo simulation number 161
# Processing Monte carlo simulation number 161
# Processing Monte carlo simulation number 162
# Processing Monte carlo simulation number 162
# Processing Monte carlo simulation number 163
# Processing Monte carlo simulation number 163
# Processing Monte carlo simulation number 164
# Processing Monte carlo simulation number 164
# Processing Monte carlo simulation number 165
# Processing Monte carlo simulation number 165
# Processing Monte carlo simulation number 166
# Processing Monte carlo simulation number 166
# Processing Monte carlo simulation number 167
# Processing Monte carlo simulation number 167
# Processing Monte carlo simulation number 168
# Processing Monte carlo simulation number 168
# Processing Monte carlo simulation number 169
# Processing Monte carlo simulation number 169
# Processing Monte carlo simulation number 170
# Processing Monte carlo simulation number 170
# Processing Monte carlo simulation number 171
# Processing Monte carlo simulation number 171
# Processing Monte carlo simulation number 172
# Processing Monte carlo simulation number 172
# Processing Monte carlo simulation number 173
# Processing Monte carlo simulation number 173
# Processing Monte carlo simulation number 174
# Processing Monte carlo simulation number 174
# Processing Monte carlo simulation number 175
# Processing Monte carlo simulation number 175
# Processing Monte carlo simulation number 176
# Processing Monte carlo simulation number 176
# Processing Monte carlo simulation number 177
# Processing Monte carlo simulation number 177
# Processing Monte carlo simulation number 178
# Processing Monte carlo simulation number 178
# Processing Monte carlo simulation number 179
# Processing Monte carlo simulation number 179
# Processing Monte carlo simulation number 180
# Processing Monte carlo simulation number 180
# Processing Monte carlo simulation number 181
# Processing Monte carlo simulation number 181
# Processing Monte carlo simulation number 182
# Processing Monte carlo simulation number 182
# Processing Monte carlo simulation number 183
# Processing Monte carlo simulation number 183
# Processing Monte carlo simulation number 184
# Processing Monte carlo simulation number 184
# Processing Monte carlo simulation number 185
# Processing Monte carlo simulation number 185
# Processing Monte carlo simulation number 186
# Processing Monte carlo simulation number 186
# Processing Monte carlo simulation number 187
# Processing Monte carlo simulation number 187
# Processing Monte carlo simulation number 188
# Processing Monte carlo simulation number 188
# Processing Monte carlo simulation number 189
# Processing Monte carlo simulation number 189
# Processing Monte carlo simulation number 190
# Processing Monte carlo simulation number 190
# Processing Monte carlo simulation number 191
# Processing Monte carlo simulation number 191
# Processing Monte carlo simulation number 192
# Processing Monte carlo simulation number 192
# Processing Monte carlo simulation number 193
# Processing Monte carlo simulation number 193
# Processing Monte carlo simulation number 194
# Processing Monte carlo simulation number 194
# Processing Monte carlo simulation number 195
# Processing Monte carlo simulation number 195
# Processing Monte carlo simulation number 196
# Processing Monte carlo simulation number 196
# Processing Monte carlo simulation number 197
# Processing Monte carlo simulation number 197
# Processing Monte carlo simulation number 198
# Processing Monte carlo simulation number 198
# Processing Monte carlo simulation number 199
# Processing Monte carlo simulation number 199
# Processing Monte carlo simulation number 200
# Processing Monte carlo simulation number 200
# Processing Monte carlo simulation number 201
# Processing Monte carlo simulation number 201
# Processing Monte carlo simulation number 202
# Processing Monte carlo simulation number 202
# Processing Monte carlo simulation number 203
# Processing Monte carlo simulation number 203
# Processing Monte carlo simulation number 204
# Processing Monte carlo simulation number 204
# Processing Monte carlo simulation number 205
# Processing Monte carlo simulation number 205
# Processing Monte carlo simulation number 206
# Processing Monte carlo simulation number 206
# Processing Monte carlo simulation number 207
# Processing Monte carlo simulation number 207
# Processing Monte carlo simulation number 208
# Processing Monte carlo simulation number 208
# Processing Monte carlo simulation number 209
# Processing Monte carlo simulation number 209
# Processing Monte carlo simulation number 210
# Processing Monte carlo simulation number 210
# Processing Monte carlo simulation number 211
# Processing Monte carlo simulation number 211
# Processing Monte carlo simulation number 212
# Processing Monte carlo simulation number 212
# Processing Monte carlo simulation number 213
# Processing Monte carlo simulation number 213
# Processing Monte carlo simulation number 214
# Processing Monte carlo simulation number 214
# Processing Monte carlo simulation number 215
# Processing Monte carlo simulation number 215
# Processing Monte carlo simulation number 216
# Processing Monte carlo simulation number 216
# Processing Monte carlo simulation number 217
# Processing Monte carlo simulation number 217
# Processing Monte carlo simulation number 218
# Processing Monte carlo simulation number 218
# Processing Monte carlo simulation number 219
# Processing Monte carlo simulation number 219
# Processing Monte carlo simulation number 220
# Processing Monte carlo simulation number 220
# Processing Monte carlo simulation number 221
# Processing Monte carlo simulation number 221
# Processing Monte carlo simulation number 222
# Processing Monte carlo simulation number 222
# Processing Monte carlo simulation number 223
# Processing Monte carlo simulation number 223
# Processing Monte carlo simulation number 224
# Processing Monte carlo simulation number 224
# Processing Monte carlo simulation number 225
# Processing Monte carlo simulation number 225
# Processing Monte carlo simulation number 226
# Processing Monte carlo simulation number 226
# Processing Monte carlo simulation number 227
# Processing Monte carlo simulation number 227
# Processing Monte carlo simulation number 228
# Processing Monte carlo simulation number 228
# Processing Monte carlo simulation number 229
# Processing Monte carlo simulation number 229
# Processing Monte carlo simulation number 230
# Processing Monte carlo simulation number 230
# Processing Monte carlo simulation number 231
# Processing Monte carlo simulation number 231
# Processing Monte carlo simulation number 232
# Processing Monte carlo simulation number 232
# Processing Monte carlo simulation number 233
# Processing Monte carlo simulation number 233
# Processing Monte carlo simulation number 234
# Processing Monte carlo simulation number 234
# Processing Monte carlo simulation number 235
# Processing Monte carlo simulation number 235
# Processing Monte carlo simulation number 236
# Processing Monte carlo simulation number 236
# Processing Monte carlo simulation number 237
# Processing Monte carlo simulation number 237
# Processing Monte carlo simulation number 238
# Processing Monte carlo simulation number 238
# Processing Monte carlo simulation number 239
# Processing Monte carlo simulation number 239
# Processing Monte carlo simulation number 240
# Processing Monte carlo simulation number 240
# Processing Monte carlo simulation number 241
# Processing Monte carlo simulation number 241
# Processing Monte carlo simulation number 242
# Processing Monte carlo simulation number 242
# Processing Monte carlo simulation number 243
# Processing Monte carlo simulation number 243
# Processing Monte carlo simulation number 244
# Processing Monte carlo simulation number 244
# Processing Monte carlo simulation number 245
# Processing Monte carlo simulation number 245
# Processing Monte carlo simulation number 246
# Processing Monte carlo simulation number 246
# Processing Monte carlo simulation number 247
# Processing Monte carlo simulation number 247
# Processing Monte carlo simulation number 248
# Processing Monte carlo simulation number 248
# Processing Monte carlo simulation number 249
# Processing Monte carlo simulation number 249
# Processing Monte carlo simulation number 250
# Processing Monte carlo simulation number 250
# Processing Monte carlo simulation number 251
# Processing Monte carlo simulation number 251
# Processing Monte carlo simulation number 252
# Processing Monte carlo simulation number 252
# Processing Monte carlo simulation number 253
# Processing Monte carlo simulation number 253
# Processing Monte carlo simulation number 254
# Processing Monte carlo simulation number 254
# Processing Monte carlo simulation number 255
# Processing Monte carlo simulation number 255
# Processing Monte carlo simulation number 256
# Processing Monte carlo simulation number 256
# Processing Monte carlo simulation number 257
# Processing Monte carlo simulation number 257
# Processing Monte carlo simulation number 258
# Processing Monte carlo simulation number 258
# Processing Monte carlo simulation number 259
# Processing Monte carlo simulation number 259
# Processing Monte carlo simulation number 260
# Processing Monte carlo simulation number 260
# Processing Monte carlo simulation number 261
# Processing Monte carlo simulation number 261
# Processing Monte carlo simulation number 262
# Processing Monte carlo simulation number 262
# Processing Monte carlo simulation number 263
# Processing Monte carlo simulation number 263
# Processing Monte carlo simulation number 264
# Processing Monte carlo simulation number 264
# Processing Monte carlo simulation number 265
# Processing Monte carlo simulation number 265
# Processing Monte carlo simulation number 266
# Processing Monte carlo simulation number 266
# Processing Monte carlo simulation number 267
# Processing Monte carlo simulation number 267
# Processing Monte carlo simulation number 268
# Processing Monte carlo simulation number 268
# Processing Monte carlo simulation number 269
# Processing Monte carlo simulation number 269
# Processing Monte carlo simulation number 270
# Processing Monte carlo simulation number 270
# Processing Monte carlo simulation number 271
# Processing Monte carlo simulation number 271
# Processing Monte carlo simulation number 272
# Processing Monte carlo simulation number 272
# Processing Monte carlo simulation number 273
# Processing Monte carlo simulation number 273
# Processing Monte carlo simulation number 274
# Processing Monte carlo simulation number 274
# Processing Monte carlo simulation number 275
# Processing Monte carlo simulation number 275
# Processing Monte carlo simulation number 276
# Processing Monte carlo simulation number 276
# Processing Monte carlo simulation number 277
# Processing Monte carlo simulation number 277
# Processing Monte carlo simulation number 278
# Processing Monte carlo simulation number 278
# Processing Monte carlo simulation number 279
# Processing Monte carlo simulation number 279
# Processing Monte carlo simulation number 280
# Processing Monte carlo simulation number 280
# Processing Monte carlo simulation number 281
# Processing Monte carlo simulation number 281
# Processing Monte carlo simulation number 282
# Processing Monte carlo simulation number 282
# Processing Monte carlo simulation number 283
# Processing Monte carlo simulation number 283
# Processing Monte carlo simulation number 284
# Processing Monte carlo simulation number 284
# Processing Monte carlo simulation number 285
# Processing Monte carlo simulation number 285
# Processing Monte carlo simulation number 286
# Processing Monte carlo simulation number 286
# Processing Monte carlo simulation number 287
# Processing Monte carlo simulation number 287
# Processing Monte carlo simulation number 288
# Processing Monte carlo simulation number 288
# Processing Monte carlo simulation number 289
# Processing Monte carlo simulation number 289
# Processing Monte carlo simulation number 290
# Processing Monte carlo simulation number 290
# Processing Monte carlo simulation number 291
# Processing Monte carlo simulation number 291
# Processing Monte carlo simulation number 292
# Processing Monte carlo simulation number 292
# Processing Monte carlo simulation number 293
# Processing Monte carlo simulation number 293
# Processing Monte carlo simulation number 294
# Processing Monte carlo simulation number 294
# Processing Monte carlo simulation number 295
# Processing Monte carlo simulation number 295
# Processing Monte carlo simulation number 296
# Processing Monte carlo simulation number 296
# Processing Monte carlo simulation number 297
# Processing Monte carlo simulation number 297
# Processing Monte carlo simulation number 298
# Processing Monte carlo simulation number 298
# Processing Monte carlo simulation number 299
# Processing Monte carlo simulation number 299
# Processing Monte carlo simulation number 300
# Processing Monte carlo simulation number 300
# Processing Monte carlo simulation number 301
# Processing Monte carlo simulation number 301
# Processing Monte carlo simulation number 302
# Processing Monte carlo simulation number 302
# Processing Monte carlo simulation number 303
# Processing Monte carlo simulation number 303
# Processing Monte carlo simulation number 304
# Processing Monte carlo simulation number 304
# Processing Monte carlo simulation number 305
# Processing Monte carlo simulation number 305
# Processing Monte carlo simulation number 306
# Processing Monte carlo simulation number 306
# Processing Monte carlo simulation number 307
# Processing Monte carlo simulation number 307
# Processing Monte carlo simulation number 308
# Processing Monte carlo simulation number 308
# Processing Monte carlo simulation number 309
# Processing Monte carlo simulation number 309
# Processing Monte carlo simulation number 310
# Processing Monte carlo simulation number 310
# Processing Monte carlo simulation number 311
# Processing Monte carlo simulation number 311
# Processing Monte carlo simulation number 312
# Processing Monte carlo simulation number 312
# Processing Monte carlo simulation number 313
# Processing Monte carlo simulation number 313
# Processing Monte carlo simulation number 314
# Processing Monte carlo simulation number 314
# Processing Monte carlo simulation number 315
# Processing Monte carlo simulation number 315
# Processing Monte carlo simulation number 316
# Processing Monte carlo simulation number 316
# Processing Monte carlo simulation number 317
# Processing Monte carlo simulation number 317
# Processing Monte carlo simulation number 318
# Processing Monte carlo simulation number 318
# Processing Monte carlo simulation number 319
# Processing Monte carlo simulation number 319
# Processing Monte carlo simulation number 320
# Processing Monte carlo simulation number 320
# Processing Monte carlo simulation number 321
# Processing Monte carlo simulation number 321
# Processing Monte carlo simulation number 322
# Processing Monte carlo simulation number 322
# Processing Monte carlo simulation number 323
# Processing Monte carlo simulation number 323
# Processing Monte carlo simulation number 324
# Processing Monte carlo simulation number 324
# Processing Monte carlo simulation number 325
# Processing Monte carlo simulation number 325
# Processing Monte carlo simulation number 326
# Processing Monte carlo simulation number 326
# Processing Monte carlo simulation number 327
# Processing Monte carlo simulation number 327
# Processing Monte carlo simulation number 328
# Processing Monte carlo simulation number 328
# Processing Monte carlo simulation number 329
# Processing Monte carlo simulation number 329
# Processing Monte carlo simulation number 330
# Processing Monte carlo simulation number 330
# Processing Monte carlo simulation number 331
# Processing Monte carlo simulation number 331
# Processing Monte carlo simulation number 332
# Processing Monte carlo simulation number 332
# Processing Monte carlo simulation number 333
# Processing Monte carlo simulation number 333
# Processing Monte carlo simulation number 334
# Processing Monte carlo simulation number 334
# Processing Monte carlo simulation number 335
# Processing Monte carlo simulation number 335
# Processing Monte carlo simulation number 336
# Processing Monte carlo simulation number 336
# Processing Monte carlo simulation number 337
# Processing Monte carlo simulation number 337
# Processing Monte carlo simulation number 338
# Processing Monte carlo simulation number 338
# Processing Monte carlo simulation number 339
# Processing Monte carlo simulation number 339
# Processing Monte carlo simulation number 340
# Processing Monte carlo simulation number 340
# Processing Monte carlo simulation number 341
# Processing Monte carlo simulation number 341
# Processing Monte carlo simulation number 342
# Processing Monte carlo simulation number 342
# Processing Monte carlo simulation number 343
# Processing Monte carlo simulation number 343
# Processing Monte carlo simulation number 344
# Processing Monte carlo simulation number 344
# Processing Monte carlo simulation number 345
# Processing Monte carlo simulation number 345
# Processing Monte carlo simulation number 346
# Processing Monte carlo simulation number 346
# Processing Monte carlo simulation number 347
# Processing Monte carlo simulation number 347
# Processing Monte carlo simulation number 348
# Processing Monte carlo simulation number 348
# Processing Monte carlo simulation number 349
# Processing Monte carlo simulation number 349
# Processing Monte carlo simulation number 350
# Processing Monte carlo simulation number 350
# Processing Monte carlo simulation number 351
# Processing Monte carlo simulation number 351
# Processing Monte carlo simulation number 352
# Processing Monte carlo simulation number 352
# Processing Monte carlo simulation number 353
# Processing Monte carlo simulation number 353
# Processing Monte carlo simulation number 354
# Processing Monte carlo simulation number 354
# Processing Monte carlo simulation number 355
# Processing Monte carlo simulation number 355
# Processing Monte carlo simulation number 356
# Processing Monte carlo simulation number 356
# Processing Monte carlo simulation number 357
# Processing Monte carlo simulation number 357
# Processing Monte carlo simulation number 358
# Processing Monte carlo simulation number 358
# Processing Monte carlo simulation number 359
# Processing Monte carlo simulation number 359
# Processing Monte carlo simulation number 360
# Processing Monte carlo simulation number 360
# Processing Monte carlo simulation number 361
# Processing Monte carlo simulation number 361
# Processing Monte carlo simulation number 362
# Processing Monte carlo simulation number 362
# Processing Monte carlo simulation number 363
# Processing Monte carlo simulation number 363
# Processing Monte carlo simulation number 364
# Processing Monte carlo simulation number 364
# Processing Monte carlo simulation number 365
# Processing Monte carlo simulation number 365
# Processing Monte carlo simulation number 366
# Processing Monte carlo simulation number 366
# Processing Monte carlo simulation number 367
# Processing Monte carlo simulation number 367
# Processing Monte carlo simulation number 368
# Processing Monte carlo simulation number 368
# Processing Monte carlo simulation number 369
# Processing Monte carlo simulation number 369
# Processing Monte carlo simulation number 370
# Processing Monte carlo simulation number 370
# Processing Monte carlo simulation number 371
# Processing Monte carlo simulation number 371
# Processing Monte carlo simulation number 372
# Processing Monte carlo simulation number 372
# Processing Monte carlo simulation number 373
# Processing Monte carlo simulation number 373
# Processing Monte carlo simulation number 374
# Processing Monte carlo simulation number 374
# Processing Monte carlo simulation number 375
# Processing Monte carlo simulation number 375
# Processing Monte carlo simulation number 376
# Processing Monte carlo simulation number 376
# Processing Monte carlo simulation number 377
# Processing Monte carlo simulation number 377
# Processing Monte carlo simulation number 378
# Processing Monte carlo simulation number 378
# Processing Monte carlo simulation number 379
# Processing Monte carlo simulation number 379
# Processing Monte carlo simulation number 380
# Processing Monte carlo simulation number 380
# Processing Monte carlo simulation number 381
# Processing Monte carlo simulation number 381
# Processing Monte carlo simulation number 382
# Processing Monte carlo simulation number 382
# Processing Monte carlo simulation number 383
# Processing Monte carlo simulation number 383
# Processing Monte carlo simulation number 384
# Processing Monte carlo simulation number 384
# Processing Monte carlo simulation number 385
# Processing Monte carlo simulation number 385
# Processing Monte carlo simulation number 386
# Processing Monte carlo simulation number 386
# Processing Monte carlo simulation number 387
# Processing Monte carlo simulation number 387
# Processing Monte carlo simulation number 388
# Processing Monte carlo simulation number 388
# Processing Monte carlo simulation number 389
# Processing Monte carlo simulation number 389
# Processing Monte carlo simulation number 390
# Processing Monte carlo simulation number 390
# Processing Monte carlo simulation number 391
# Processing Monte carlo simulation number 391
# Processing Monte carlo simulation number 392
# Processing Monte carlo simulation number 392
# Processing Monte carlo simulation number 393
# Processing Monte carlo simulation number 393
# Processing Monte carlo simulation number 394
# Processing Monte carlo simulation number 394
# Processing Monte carlo simulation number 395
# Processing Monte carlo simulation number 395
# Processing Monte carlo simulation number 396
# Processing Monte carlo simulation number 396
# Processing Monte carlo simulation number 397
# Processing Monte carlo simulation number 397
# Processing Monte carlo simulation number 398
# Processing Monte carlo simulation number 398
# Processing Monte carlo simulation number 399
# Processing Monte carlo simulation number 399
# Processing Monte carlo simulation number 400
# Processing Monte carlo simulation number 400
# Processing Monte carlo simulation number 401
# Processing Monte carlo simulation number 401
# Processing Monte carlo simulation number 402
# Processing Monte carlo simulation number 402
# Processing Monte carlo simulation number 403
# Processing Monte carlo simulation number 403
# Processing Monte carlo simulation number 404
# Processing Monte carlo simulation number 404
# Processing Monte carlo simulation number 405
# Processing Monte carlo simulation number 405
# Processing Monte carlo simulation number 406
# Processing Monte carlo simulation number 406
# Processing Monte carlo simulation number 407
# Processing Monte carlo simulation number 407
# Processing Monte carlo simulation number 408
# Processing Monte carlo simulation number 408
# Processing Monte carlo simulation number 409
# Processing Monte carlo simulation number 409
# Processing Monte carlo simulation number 410
# Processing Monte carlo simulation number 410
# Processing Monte carlo simulation number 411
# Processing Monte carlo simulation number 411
# Processing Monte carlo simulation number 412
# Processing Monte carlo simulation number 412
# Processing Monte carlo simulation number 413
# Processing Monte carlo simulation number 413
# Processing Monte carlo simulation number 414
# Processing Monte carlo simulation number 414
# Processing Monte carlo simulation number 415
# Processing Monte carlo simulation number 415
# Processing Monte carlo simulation number 416
# Processing Monte carlo simulation number 416
# Processing Monte carlo simulation number 417
# Processing Monte carlo simulation number 417
# Processing Monte carlo simulation number 418
# Processing Monte carlo simulation number 418
# Processing Monte carlo simulation number 419
# Processing Monte carlo simulation number 419
# Processing Monte carlo simulation number 420
# Processing Monte carlo simulation number 420
# Processing Monte carlo simulation number 421
# Processing Monte carlo simulation number 421
# Processing Monte carlo simulation number 422
# Processing Monte carlo simulation number 422
# Processing Monte carlo simulation number 423
# Processing Monte carlo simulation number 423
# Processing Monte carlo simulation number 424
# Processing Monte carlo simulation number 424
# Processing Monte carlo simulation number 425
# Processing Monte carlo simulation number 425
# Processing Monte carlo simulation number 426
# Processing Monte carlo simulation number 426
# Processing Monte carlo simulation number 427
# Processing Monte carlo simulation number 427
# Processing Monte carlo simulation number 428
# Processing Monte carlo simulation number 428
# Processing Monte carlo simulation number 429
# Processing Monte carlo simulation number 429
# Processing Monte carlo simulation number 430
# Processing Monte carlo simulation number 430
# Processing Monte carlo simulation number 431
# Processing Monte carlo simulation number 431
# Processing Monte carlo simulation number 432
# Processing Monte carlo simulation number 432
# Processing Monte carlo simulation number 433
# Processing Monte carlo simulation number 433
# Processing Monte carlo simulation number 434
# Processing Monte carlo simulation number 434
# Processing Monte carlo simulation number 435
# Processing Monte carlo simulation number 435
# Processing Monte carlo simulation number 436
# Processing Monte carlo simulation number 436
# Processing Monte carlo simulation number 437
# Processing Monte carlo simulation number 437
# Processing Monte carlo simulation number 438
# Processing Monte carlo simulation number 438
# Processing Monte carlo simulation number 439
# Processing Monte carlo simulation number 439
# Processing Monte carlo simulation number 440
# Processing Monte carlo simulation number 440
# Processing Monte carlo simulation number 441
# Processing Monte carlo simulation number 441
# Processing Monte carlo simulation number 442
# Processing Monte carlo simulation number 442
# Processing Monte carlo simulation number 443
# Processing Monte carlo simulation number 443
# Processing Monte carlo simulation number 444
# Processing Monte carlo simulation number 444
# Processing Monte carlo simulation number 445
# Processing Monte carlo simulation number 445
# Processing Monte carlo simulation number 446
# Processing Monte carlo simulation number 446
# Processing Monte carlo simulation number 447
# Processing Monte carlo simulation number 447
# Processing Monte carlo simulation number 448
# Processing Monte carlo simulation number 448
# Processing Monte carlo simulation number 449
# Processing Monte carlo simulation number 449
# Processing Monte carlo simulation number 450
# Processing Monte carlo simulation number 450
# Processing Monte carlo simulation number 451
# Processing Monte carlo simulation number 451
# Processing Monte carlo simulation number 452
# Processing Monte carlo simulation number 452
# Processing Monte carlo simulation number 453
# Processing Monte carlo simulation number 453
# Processing Monte carlo simulation number 454
# Processing Monte carlo simulation number 454
# Processing Monte carlo simulation number 455
# Processing Monte carlo simulation number 455
# Processing Monte carlo simulation number 456
# Processing Monte carlo simulation number 456
# Processing Monte carlo simulation number 457
# Processing Monte carlo simulation number 457
# Processing Monte carlo simulation number 458
# Processing Monte carlo simulation number 458
# Processing Monte carlo simulation number 459
# Processing Monte carlo simulation number 459
# Processing Monte carlo simulation number 460
# Processing Monte carlo simulation number 460
# Processing Monte carlo simulation number 461
# Processing Monte carlo simulation number 461
# Processing Monte carlo simulation number 462
# Processing Monte carlo simulation number 462
# Processing Monte carlo simulation number 463
# Processing Monte carlo simulation number 463
# Processing Monte carlo simulation number 464
# Processing Monte carlo simulation number 464
# Processing Monte carlo simulation number 465
# Processing Monte carlo simulation number 465
# Processing Monte carlo simulation number 466
# Processing Monte carlo simulation number 466
# Processing Monte carlo simulation number 467
# Processing Monte carlo simulation number 467
# Processing Monte carlo simulation number 468
# Processing Monte carlo simulation number 468
# Processing Monte carlo simulation number 469
# Processing Monte carlo simulation number 469
# Processing Monte carlo simulation number 470
# Processing Monte carlo simulation number 470
# Processing Monte carlo simulation number 471
# Processing Monte carlo simulation number 471
# Processing Monte carlo simulation number 472
# Processing Monte carlo simulation number 472
# Processing Monte carlo simulation number 473
# Processing Monte carlo simulation number 473
# Processing Monte carlo simulation number 474
# Processing Monte carlo simulation number 474
# Processing Monte carlo simulation number 475
# Processing Monte carlo simulation number 475
# Processing Monte carlo simulation number 476
# Processing Monte carlo simulation number 476
# Processing Monte carlo simulation number 477
# Processing Monte carlo simulation number 477
# Processing Monte carlo simulation number 478
# Processing Monte carlo simulation number 478
# Processing Monte carlo simulation number 479
# Processing Monte carlo simulation number 479
# Processing Monte carlo simulation number 480
# Processing Monte carlo simulation number 480
# Processing Monte carlo simulation number 481
# Processing Monte carlo simulation number 481
# Processing Monte carlo simulation number 482
# Processing Monte carlo simulation number 482
# Processing Monte carlo simulation number 483
# Processing Monte carlo simulation number 483
# Processing Monte carlo simulation number 484
# Processing Monte carlo simulation number 484
# Processing Monte carlo simulation number 485
# Processing Monte carlo simulation number 485
# Processing Monte carlo simulation number 486
# Processing Monte carlo simulation number 486
# Processing Monte carlo simulation number 487
# Processing Monte carlo simulation number 487
# Processing Monte carlo simulation number 488
# Processing Monte carlo simulation number 488
# Processing Monte carlo simulation number 489
# Processing Monte carlo simulation number 489
# Processing Monte carlo simulation number 490
# Processing Monte carlo simulation number 490
# Processing Monte carlo simulation number 491
# Processing Monte carlo simulation number 491
# Processing Monte carlo simulation number 492
# Processing Monte carlo simulation number 492
# Processing Monte carlo simulation number 493
# Processing Monte carlo simulation number 493
# Processing Monte carlo simulation number 494
# Processing Monte carlo simulation number 494
# Processing Monte carlo simulation number 495
# Processing Monte carlo simulation number 495
# Processing Monte carlo simulation number 496
# Processing Monte carlo simulation number 496
# Processing Monte carlo simulation number 497
# Processing Monte carlo simulation number 497
# Processing Monte carlo simulation number 498
# Processing Monte carlo simulation number 498
# Processing Monte carlo simulation number 499
# Processing Monte carlo simulation number 499
# Processing Monte carlo simulation number 500
# Processing Monte carlo simulation number 500
# Processing Monte carlo simulation number 501
# Processing Monte carlo simulation number 501
# Processing Monte carlo simulation number 502
# Processing Monte carlo simulation number 502
# Processing Monte carlo simulation number 503
# Processing Monte carlo simulation number 503
# Processing Monte carlo simulation number 504
# Processing Monte carlo simulation number 504
# Processing Monte carlo simulation number 505
# Processing Monte carlo simulation number 505
# Processing Monte carlo simulation number 506
# Processing Monte carlo simulation number 506
# Processing Monte carlo simulation number 507
# Processing Monte carlo simulation number 507
# Processing Monte carlo simulation number 508
# Processing Monte carlo simulation number 508
# Processing Monte carlo simulation number 509
# Processing Monte carlo simulation number 509
# Processing Monte carlo simulation number 510
# Processing Monte carlo simulation number 510
# Processing Monte carlo simulation number 511
# Processing Monte carlo simulation number 511
# Processing Monte carlo simulation number 512
# Processing Monte carlo simulation number 512
# Processing Monte carlo simulation number 513
# Processing Monte carlo simulation number 513
# Processing Monte carlo simulation number 514
# Processing Monte carlo simulation number 514
# Processing Monte carlo simulation number 515
# Processing Monte carlo simulation number 515
# Processing Monte carlo simulation number 516
# Processing Monte carlo simulation number 516
# Processing Monte carlo simulation number 517
# Processing Monte carlo simulation number 517
# Processing Monte carlo simulation number 518
# Processing Monte carlo simulation number 518
# Processing Monte carlo simulation number 519
# Processing Monte carlo simulation number 519
# Processing Monte carlo simulation number 520
# Processing Monte carlo simulation number 520
# Processing Monte carlo simulation number 521
# Processing Monte carlo simulation number 521
# Processing Monte carlo simulation number 522
# Processing Monte carlo simulation number 522
# Processing Monte carlo simulation number 523
# Processing Monte carlo simulation number 523
# Processing Monte carlo simulation number 524
# Processing Monte carlo simulation number 524
# Processing Monte carlo simulation number 525
# Processing Monte carlo simulation number 525
# Processing Monte carlo simulation number 526
# Processing Monte carlo simulation number 526
# Processing Monte carlo simulation number 527
# Processing Monte carlo simulation number 527
# Processing Monte carlo simulation number 528
# Processing Monte carlo simulation number 528
# Processing Monte carlo simulation number 529
# Processing Monte carlo simulation number 529
# Processing Monte carlo simulation number 530
# Processing Monte carlo simulation number 530
# Processing Monte carlo simulation number 531
# Processing Monte carlo simulation number 531
# Processing Monte carlo simulation number 532
# Processing Monte carlo simulation number 532
# Processing Monte carlo simulation number 533
# Processing Monte carlo simulation number 533
# Processing Monte carlo simulation number 534
# Processing Monte carlo simulation number 534
# Processing Monte carlo simulation number 535
# ...
# Processing Monte carlo simulation number 1826
# Processing Monte carlo simulation number 1827
# Processing Monte carlo simulation number 1827
# Processing Monte carlo simulation number 1828
# Processing Monte carlo simulation number 1828
# Processing Monte carlo simulation number 1829
# Processing Monte carlo simulation number 1829
# Processing Monte carlo simulation number 1830
# Processing Monte carlo simulation number 1830
# Processing Monte carlo simulation number 1831
# Processing Monte carlo simulation number 1831
# Processing Monte carlo simulation number 1832
# Processing Monte carlo simulation number 1832
# Processing Monte carlo simulation number 1833
# Processing Monte carlo simulation number 1833
# Processing Monte carlo simulation number 1834
# Processing Monte carlo simulation number 1834
# Processing Monte carlo simulation number 1835
# Processing Monte carlo simulation number 1835
# Processing Monte carlo simulation number 1836
# Processing Monte carlo simulation number 1836
# Processing Monte carlo simulation number 1837
# Processing Monte carlo simulation number 1837
# Processing Monte carlo simulation number 1838
# Processing Monte carlo simulation number 1838
# Processing Monte carlo simulation number 1839
# Processing Monte carlo simulation number 1839
# Processing Monte carlo simulation number 1840
# Processing Monte carlo simulation number 1840
# Processing Monte carlo simulation number 1841
# Processing Monte carlo simulation number 1841
# Processing Monte carlo simulation number 1842
# Processing Monte carlo simulation number 1842
# Processing Monte carlo simulation number 1843
# Processing Monte carlo simulation number 1843
# Processing Monte carlo simulation number 1844
# Processing Monte carlo simulation number 1844
# Processing Monte carlo simulation number 1845
# Processing Monte carlo simulation number 1845
# Processing Monte carlo simulation number 1846
# Processing Monte carlo simulation number 1846
# Processing Monte carlo simulation number 1847
# Processing Monte carlo simulation number 1847
# Processing Monte carlo simulation number 1848
# Processing Monte carlo simulation number 1848
# Processing Monte carlo simulation number 1849
# Processing Monte carlo simulation number 1849
# Processing Monte carlo simulation number 1850
# Processing Monte carlo simulation number 1850
# Processing Monte carlo simulation number 1851
# Processing Monte carlo simulation number 1851
# Processing Monte carlo simulation number 1852
# Processing Monte carlo simulation number 1852
# Processing Monte carlo simulation number 1853
# Processing Monte carlo simulation number 1853
# Processing Monte carlo simulation number 1854
# Processing Monte carlo simulation number 1854
# Processing Monte carlo simulation number 1855
# Processing Monte carlo simulation number 1855
# Processing Monte carlo simulation number 1856
# Processing Monte carlo simulation number 1856
# Processing Monte carlo simulation number 1857
# Processing Monte carlo simulation number 1857
# Processing Monte carlo simulation number 1858
# Processing Monte carlo simulation number 1858
# Processing Monte carlo simulation number 1859
# Processing Monte carlo simulation number 1859
# Processing Monte carlo simulation number 1860
# Processing Monte carlo simulation number 1860
# Processing Monte carlo simulation number 1861
# Processing Monte carlo simulation number 1861
# Processing Monte carlo simulation number 1862
# Processing Monte carlo simulation number 1862
# Processing Monte carlo simulation number 1863
# Processing Monte carlo simulation number 1863
# Processing Monte carlo simulation number 1864
# Processing Monte carlo simulation number 1864
# Processing Monte carlo simulation number 1865
# Processing Monte carlo simulation number 1865
# Processing Monte carlo simulation number 1866
# Processing Monte carlo simulation number 1866
# Processing Monte carlo simulation number 1867
# Processing Monte carlo simulation number 1867
# Processing Monte carlo simulation number 1868
# Processing Monte carlo simulation number 1868
# Processing Monte carlo simulation number 1869
# Processing Monte carlo simulation number 1869
# Processing Monte carlo simulation number 1870
# Processing Monte carlo simulation number 1870
# Processing Monte carlo simulation number 1871
# Processing Monte carlo simulation number 1871
# Processing Monte carlo simulation number 1872
# Processing Monte carlo simulation number 1872
# Processing Monte carlo simulation number 1873
# Processing Monte carlo simulation number 1873
# Processing Monte carlo simulation number 1874
# Processing Monte carlo simulation number 1874
# Processing Monte carlo simulation number 1875
# Processing Monte carlo simulation number 1875
# Processing Monte carlo simulation number 1876
# Processing Monte carlo simulation number 1876
# Processing Monte carlo simulation number 1877
# Processing Monte carlo simulation number 1877
# Processing Monte carlo simulation number 1878
# Processing Monte carlo simulation number 1878
# Processing Monte carlo simulation number 1879
# Processing Monte carlo simulation number 1879
# Processing Monte carlo simulation number 1880
# Processing Monte carlo simulation number 1880
# Processing Monte carlo simulation number 1881
# Processing Monte carlo simulation number 1881
# Processing Monte carlo simulation number 1882
# Processing Monte carlo simulation number 1882
# Processing Monte carlo simulation number 1883
# Processing Monte carlo simulation number 1883
# Processing Monte carlo simulation number 1884
# Processing Monte carlo simulation number 1884
# Processing Monte carlo simulation number 1885
# Processing Monte carlo simulation number 1885
# Processing Monte carlo simulation number 1886
# Processing Monte carlo simulation number 1886
# Processing Monte carlo simulation number 1887
# Processing Monte carlo simulation number 1887
# Processing Monte carlo simulation number 1888
# Processing Monte carlo simulation number 1888
# Processing Monte carlo simulation number 1889
# Processing Monte carlo simulation number 1889
# Processing Monte carlo simulation number 1890
# Processing Monte carlo simulation number 1890
# Processing Monte carlo simulation number 1891
# Processing Monte carlo simulation number 1891
# Processing Monte carlo simulation number 1892
# Processing Monte carlo simulation number 1892
# Processing Monte carlo simulation number 1893
# Processing Monte carlo simulation number 1893
# Processing Monte carlo simulation number 1894
# Processing Monte carlo simulation number 1894
# Processing Monte carlo simulation number 1895
# Processing Monte carlo simulation number 1895
# Processing Monte carlo simulation number 1896
# Processing Monte carlo simulation number 1896
# Processing Monte carlo simulation number 1897
# Processing Monte carlo simulation number 1897
# Processing Monte carlo simulation number 1898
# Processing Monte carlo simulation number 1898
# Processing Monte carlo simulation number 1899
# Processing Monte carlo simulation number 1899
# Processing Monte carlo simulation number 1900
# Processing Monte carlo simulation number 1900
# Processing Monte carlo simulation number 1901
# Processing Monte carlo simulation number 1901
# Processing Monte carlo simulation number 1902
# Processing Monte carlo simulation number 1902
# Processing Monte carlo simulation number 1903
# Processing Monte carlo simulation number 1903
# Processing Monte carlo simulation number 1904
# Processing Monte carlo simulation number 1904
# Processing Monte carlo simulation number 1905
# Processing Monte carlo simulation number 1905
# Processing Monte carlo simulation number 1906
# Processing Monte carlo simulation number 1906
# Processing Monte carlo simulation number 1907
# Processing Monte carlo simulation number 1907
# Processing Monte carlo simulation number 1908
# Processing Monte carlo simulation number 1908
# Processing Monte carlo simulation number 1909
# Processing Monte carlo simulation number 1909
# Processing Monte carlo simulation number 1910
# Processing Monte carlo simulation number 1910
# Processing Monte carlo simulation number 1911
# Processing Monte carlo simulation number 1911
# Processing Monte carlo simulation number 1912
# Processing Monte carlo simulation number 1912
# Processing Monte carlo simulation number 1913
# Processing Monte carlo simulation number 1913
# Processing Monte carlo simulation number 1914
# Processing Monte carlo simulation number 1914
# Processing Monte carlo simulation number 1915
# Processing Monte carlo simulation number 1915
# Processing Monte carlo simulation number 1916
# Processing Monte carlo simulation number 1916
# Processing Monte carlo simulation number 1917
# Processing Monte carlo simulation number 1917
# Processing Monte carlo simulation number 1918
# Processing Monte carlo simulation number 1918
# Processing Monte carlo simulation number 1919
# Processing Monte carlo simulation number 1919
# Processing Monte carlo simulation number 1920
# Processing Monte carlo simulation number 1920
# Processing Monte carlo simulation number 1921
# Processing Monte carlo simulation number 1921
# Processing Monte carlo simulation number 1922
# Processing Monte carlo simulation number 1922
# Processing Monte carlo simulation number 1923
# Processing Monte carlo simulation number 1923
# Processing Monte carlo simulation number 1924
# Processing Monte carlo simulation number 1924
# Processing Monte carlo simulation number 1925
# Processing Monte carlo simulation number 1925
# Processing Monte carlo simulation number 1926
# Processing Monte carlo simulation number 1926
# Processing Monte carlo simulation number 1927
# Processing Monte carlo simulation number 1927
# Processing Monte carlo simulation number 1928
# Processing Monte carlo simulation number 1928
# Processing Monte carlo simulation number 1929
# Processing Monte carlo simulation number 1929
# Processing Monte carlo simulation number 1930
# Processing Monte carlo simulation number 1930
# Processing Monte carlo simulation number 1931
# Processing Monte carlo simulation number 1931
# Processing Monte carlo simulation number 1932
# Processing Monte carlo simulation number 1932
# Processing Monte carlo simulation number 1933
# Processing Monte carlo simulation number 1933
# Processing Monte carlo simulation number 1934
# Processing Monte carlo simulation number 1934
# Processing Monte carlo simulation number 1935
# Processing Monte carlo simulation number 1935
# Processing Monte carlo simulation number 1936
# Processing Monte carlo simulation number 1936
# Processing Monte carlo simulation number 1937
# Processing Monte carlo simulation number 1937
# Processing Monte carlo simulation number 1938
# Processing Monte carlo simulation number 1938
# Processing Monte carlo simulation number 1939
# Processing Monte carlo simulation number 1939
# Processing Monte carlo simulation number 1940
# Processing Monte carlo simulation number 1940
# Processing Monte carlo simulation number 1941
# Processing Monte carlo simulation number 1941
# Processing Monte carlo simulation number 1942
# Processing Monte carlo simulation number 1942
# Processing Monte carlo simulation number 1943
# Processing Monte carlo simulation number 1943
# Processing Monte carlo simulation number 1944
# Processing Monte carlo simulation number 1944
# Processing Monte carlo simulation number 1945
# Processing Monte carlo simulation number 1945
# Processing Monte carlo simulation number 1946
# Processing Monte carlo simulation number 1946
# Processing Monte carlo simulation number 1947
# Processing Monte carlo simulation number 1947
# Processing Monte carlo simulation number 1948
# Processing Monte carlo simulation number 1948
# Processing Monte carlo simulation number 1949
# Processing Monte carlo simulation number 1949
# Processing Monte carlo simulation number 1950
# Processing Monte carlo simulation number 1950
# Processing Monte carlo simulation number 1951
# Processing Monte carlo simulation number 1951
# Processing Monte carlo simulation number 1952
# Processing Monte carlo simulation number 1952
# Processing Monte carlo simulation number 1953
# Processing Monte carlo simulation number 1953
# Processing Monte carlo simulation number 1954
# Processing Monte carlo simulation number 1954
# Processing Monte carlo simulation number 1955
# Processing Monte carlo simulation number 1955
# Processing Monte carlo simulation number 1956
# Processing Monte carlo simulation number 1956
# Processing Monte carlo simulation number 1957
# Processing Monte carlo simulation number 1957
# Processing Monte carlo simulation number 1958
# Processing Monte carlo simulation number 1958
# Processing Monte carlo simulation number 1959
# Processing Monte carlo simulation number 1959
# Processing Monte carlo simulation number 1960
# Processing Monte carlo simulation number 1960
# Processing Monte carlo simulation number 1961
# Processing Monte carlo simulation number 1961
# Processing Monte carlo simulation number 1962
# Processing Monte carlo simulation number 1962
# Processing Monte carlo simulation number 1963
# Processing Monte carlo simulation number 1963
# Processing Monte carlo simulation number 1964
# Processing Monte carlo simulation number 1964
# Processing Monte carlo simulation number 1965
# Processing Monte carlo simulation number 1965
# Processing Monte carlo simulation number 1966
# Processing Monte carlo simulation number 1966
# Processing Monte carlo simulation number 1967
# Processing Monte carlo simulation number 1967
# Processing Monte carlo simulation number 1968
# Processing Monte carlo simulation number 1968
# Processing Monte carlo simulation number 1969
# Processing Monte carlo simulation number 1969
# Processing Monte carlo simulation number 1970
# Processing Monte carlo simulation number 1970
# Processing Monte carlo simulation number 1971
# Processing Monte carlo simulation number 1971
# Processing Monte carlo simulation number 1972
# Processing Monte carlo simulation number 1972
# Processing Monte carlo simulation number 1973
# Processing Monte carlo simulation number 1973
# Processing Monte carlo simulation number 1974
# Processing Monte carlo simulation number 1974
# Processing Monte carlo simulation number 1975
# Processing Monte carlo simulation number 1975
# Processing Monte carlo simulation number 1976
# Processing Monte carlo simulation number 1976
# Processing Monte carlo simulation number 1977
# Processing Monte carlo simulation number 1977
# Processing Monte carlo simulation number 1978
# Processing Monte carlo simulation number 1978
# Processing Monte carlo simulation number 1979
# Processing Monte carlo simulation number 1979
# Processing Monte carlo simulation number 1980
# Processing Monte carlo simulation number 1980
# Processing Monte carlo simulation number 1981
# Processing Monte carlo simulation number 1981
# Processing Monte carlo simulation number 1982
# Processing Monte carlo simulation number 1982
# Processing Monte carlo simulation number 1983
# Processing Monte carlo simulation number 1983
# Processing Monte carlo simulation number 1984
# Processing Monte carlo simulation number 1984
# Processing Monte carlo simulation number 1985
# Processing Monte carlo simulation number 1985
# Processing Monte carlo simulation number 1986
# Processing Monte carlo simulation number 1986
# Processing Monte carlo simulation number 1987
# Processing Monte carlo simulation number 1987
# Processing Monte carlo simulation number 1988
# Processing Monte carlo simulation number 1988
# Processing Monte carlo simulation number 1989
# Processing Monte carlo simulation number 1989
# Processing Monte carlo simulation number 1990
# Processing Monte carlo simulation number 1990
# Processing Monte carlo simulation number 1991
# Processing Monte carlo simulation number 1991
# Processing Monte carlo simulation number 1992
# Processing Monte carlo simulation number 1992
# Processing Monte carlo simulation number 1993
# Processing Monte carlo simulation number 1993
# Processing Monte carlo simulation number 1994
# Processing Monte carlo simulation number 1994
# Processing Monte carlo simulation number 1995
# Processing Monte carlo simulation number 1995
# Processing Monte carlo simulation number 1996
# Processing Monte carlo simulation number 1996
# Processing Monte carlo simulation number 1997
# Processing Monte carlo simulation number 1997
# Processing Monte carlo simulation number 1998
# Processing Monte carlo simulation number 1998
# Processing Monte carlo simulation number 1999
# Processing Monte carlo simulation number 1999
# 32.0

# %%
def get_delta_collapse(no_dcl: DCL_Bond,
                       dcl: DCL_Bond,
                       L_PONV: float = 0.96):
    """
    Return (years_diff, dcl_date, no_dcl_date), or (None, None, None)
    if either series never exceeds L_PONV.
    """
    # Boolean masks
    mask_dcl    = dcl.results['Leverage ratio'] > L_PONV
    mask_no_dcl = no_dcl.results['Leverage ratio'] > L_PONV

    # If either never crosses, bail out
    if not mask_dcl.any() or not mask_no_dcl.any():
        return None, None, None

    # Otherwise grab the first crossing date
    dcl_date       = dcl.results.index[mask_dcl.argmax()]
    no_dcl_date    = no_dcl.results.index[mask_no_dcl.argmax()]

    # Compute time difference in years
    delta_days     = (dcl_date - no_dcl_date).days
    years_diff     = delta_days / 365.25

    return years_diff, dcl_date, no_dcl_date


def get_delta_collapse_all(dcl_bonds: list[tuple[DCL_Bond, DCL_Bond]],
                           L_PONV: float = 0.96):
    for no_dcl, dcl in dcl_bonds:
        print(f"--- {no_dcl.name} ---")
        years_diff, dcl_date, no_dcl_date = get_delta_collapse(no_dcl, dcl, L_PONV)

        if years_diff is None:
            print(f"⚠️  Neither '{dcl.name}' nor '{no_dcl.name}' ever exceeded a leverage of {L_PONV:.2f}.")
            print()
            continue

        days_diff = int(years_diff * 365)
        print(f"Δ to reach {L_PONV:.2%}: {years_diff:.2f} years ({days_diff} days)")
        print(f" • DCL   crossed on: {dcl_date.date()}")
        print(f" • No DCL crossed on: {no_dcl_date.date()}")
        print()


get_delta_collapse_all(monte_carlo_dcls, L_PONV=0.96)

# 1) Gather all valid day‐differences
day_diffs = []
for no_dcl, dcl in monte_carlo_dcls:
    years_diff, dcl_date, no_dcl_date = get_delta_collapse(no_dcl, dcl, L_PONV=0.96)
    if years_diff is not None:
        # compute the integer day difference directly
        delta_days = (dcl_date - no_dcl_date).days
        day_diffs.append(delta_days)

# 2) Make a histogram in days
plt.figure(figsize=(8, 5))
plt.hist(day_diffs, bins=50)             # you can tweak the number of bins
plt.xlabel('Time difference (days)')
plt.ylabel('Frequency')
plt.title('Monte Carlo: Delay to reach L_PONV (0.96) in Days')
plt.grid(True, linestyle='--', alpha=0.5)

# 3) Show it
plt.tight_layout()
plt.savefig('images/monte_carlo_delay_histogram.png')
plt.show()

# 2) Compute summary stats
mean_days   = np.mean(day_diffs)
median_days = np.median(day_diffs)
std_days    = np.std(day_diffs, ddof=1)   # sample std
min_days    = np.min(day_diffs)
max_days    = np.max(day_diffs)

print(f"Mean delay   : {mean_days:.1f} days")
print(f"Median delay : {median_days:.1f} days")
print(f"Std. dev.    : {std_days:.1f} days")
print(f"Range        : {min_days} to {max_days} days")
# Calculate number times the delays are negative
print(f"Number of negative delays: {len([d for d in day_diffs if d < 0])}")
# Out:
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 6.02 years (2195 days)
#  • DCL   crossed on: 2034-06-27
#  • No DCL crossed on: 2028-06-21
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.02 years (7 days)
#  • DCL   crossed on: 2029-07-27
#  • No DCL crossed on: 2029-07-19
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.09 years (33 days)
#  • DCL   crossed on: 2031-08-27
#  • No DCL crossed on: 2031-07-24
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.44 years (161 days)
#  • DCL   crossed on: 2033-12-16
#  • No DCL crossed on: 2033-07-07
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.42 years (518 days)
#  • DCL   crossed on: 2031-09-25
#  • No DCL crossed on: 2030-04-24
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.21 years (441 days)
#  • DCL   crossed on: 2033-04-06
#  • No DCL crossed on: 2032-01-20
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.11 years (41 days)
#  • DCL   crossed on: 2030-07-11
#  • No DCL crossed on: 2030-05-30
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.02 years (6 days)
#  • DCL   crossed on: 2027-10-20
#  • No DCL crossed on: 2027-10-13
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.57 years (209 days)
#  • DCL   crossed on: 2031-07-25
#  • No DCL crossed on: 2030-12-27
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.28 years (101 days)
#  • DCL   crossed on: 2030-02-25
#  • No DCL crossed on: 2029-11-15
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.71 years (257 days)
#  • DCL   crossed on: 2031-08-12
#  • No DCL crossed on: 2030-11-27
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.26 years (460 days)
#  • DCL   crossed on: 2033-02-24
#  • No DCL crossed on: 2031-11-21
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.15 years (54 days)
#  • DCL   crossed on: 2028-11-08
#  • No DCL crossed on: 2028-09-14
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.12 years (407 days)
#  • DCL   crossed on: 2032-11-19
#  • No DCL crossed on: 2031-10-08
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.04 years (14 days)
#  • DCL   crossed on: 2031-02-21
#  • No DCL crossed on: 2031-02-06
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.40 years (146 days)
#  • DCL   crossed on: 2033-10-21
#  • No DCL crossed on: 2033-05-27
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.44 years (161 days)
#  • DCL   crossed on: 2032-01-16
#  • No DCL crossed on: 2031-08-07
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.34 years (123 days)
#  • DCL   crossed on: 2031-05-20
#  • No DCL crossed on: 2031-01-16
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.31 years (478 days)
#  • DCL   crossed on: 2033-03-25
#  • No DCL crossed on: 2031-12-02
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.20 years (71 days)
#  • DCL   crossed on: 2030-12-06
#  • No DCL crossed on: 2030-09-25
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 2.03 years (742 days)
#  • DCL   crossed on: 2032-01-29
#  • No DCL crossed on: 2030-01-16
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.80 years (291 days)
#  • DCL   crossed on: 2032-12-29
#  • No DCL crossed on: 2032-03-12
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.82 years (298 days)
#  • DCL   crossed on: 2033-02-23
#  • No DCL crossed on: 2032-04-30
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.48 years (173 days)
#  • DCL   crossed on: 2034-02-02
#  • No DCL crossed on: 2033-08-12
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.60 years (218 days)
#  • DCL   crossed on: 2033-11-16
#  • No DCL crossed on: 2033-04-11
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.16 years (58 days)
#  • DCL   crossed on: 2030-10-21
#  • No DCL crossed on: 2030-08-23
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.90 years (693 days)
#  • DCL   crossed on: 2033-11-18
#  • No DCL crossed on: 2031-12-25
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.17 years (62 days)
#  • DCL   crossed on: 2030-07-26
#  • No DCL crossed on: 2030-05-24
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.53 years (193 days)
#  • DCL   crossed on: 2033-12-13
#  • No DCL crossed on: 2033-06-02
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.22 years (80 days)
#  • DCL   crossed on: 2029-05-11
#  • No DCL crossed on: 2029-02-19
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.37 years (133 days)
#  • DCL   crossed on: 2031-10-29
#  • No DCL crossed on: 2031-06-17
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.13 years (46 days)
#  • DCL   crossed on: 2030-01-08
#  • No DCL crossed on: 2029-11-22
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.04 years (13 days)
#  • DCL   crossed on: 2028-10-10
#  • No DCL crossed on: 2028-09-26
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.45 years (163 days)
#  • DCL   crossed on: 2033-05-06
#  • No DCL crossed on: 2032-11-23
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.06 years (20 days)
#  • DCL   crossed on: 2029-04-12
#  • No DCL crossed on: 2029-03-22
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.16 years (56 days)
#  • DCL   crossed on: 2030-04-19
#  • No DCL crossed on: 2030-02-21
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.01 years (1 days)
#  • DCL   crossed on: 2032-09-02
#  • No DCL crossed on: 2032-08-31
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.82 years (664 days)
#  • DCL   crossed on: 2033-09-29
#  • No DCL crossed on: 2031-12-04
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.05 years (16 days)
#  • DCL   crossed on: 2032-11-04
#  • No DCL crossed on: 2032-10-18
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.27 years (97 days)
#  • DCL   crossed on: 2030-11-12
#  • No DCL crossed on: 2030-08-06
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.86 years (314 days)
#  • DCL   crossed on: 2033-06-30
#  • No DCL crossed on: 2032-08-19
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.21 years (77 days)
#  • DCL   crossed on: 2033-02-03
#  • No DCL crossed on: 2032-11-17
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.26 years (459 days)
#  • DCL   crossed on: 2033-11-02
#  • No DCL crossed on: 2032-07-30
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.17 years (426 days)
#  • DCL   crossed on: 2032-06-23
#  • No DCL crossed on: 2031-04-23
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.37 years (135 days)
#  • DCL   crossed on: 2033-04-21
#  • No DCL crossed on: 2032-12-06
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.48 years (175 days)
#  • DCL   crossed on: 2032-10-19
#  • No DCL crossed on: 2032-04-26
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.53 years (192 days)
#  • DCL   crossed on: 2031-08-11
#  • No DCL crossed on: 2031-01-30
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.01 years (2 days)
#  • DCL   crossed on: 2029-02-23
#  • No DCL crossed on: 2029-02-20
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.29 years (105 days)
#  • DCL   crossed on: 2028-09-01
#  • No DCL crossed on: 2028-05-18
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.19 years (434 days)
#  • DCL   crossed on: 2032-05-07
#  • No DCL crossed on: 2031-02-27
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.07 years (25 days)
#  • DCL   crossed on: 2030-11-19
#  • No DCL crossed on: 2030-10-24
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.00 years (0 days)
#  • DCL   crossed on: 2026-11-26
#  • No DCL crossed on: 2026-11-25
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.17 years (61 days)
#  • DCL   crossed on: 2029-09-03
#  • No DCL crossed on: 2029-07-03
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.25 years (91 days)
#  • DCL   crossed on: 2029-08-09
#  • No DCL crossed on: 2029-05-09
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 2.45 years (894 days)
#  • DCL   crossed on: 2034-05-24
#  • No DCL crossed on: 2031-12-11
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.47 years (170 days)
#  • DCL   crossed on: 2029-02-22
#  • No DCL crossed on: 2028-09-04
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.69 years (252 days)
#  • DCL   crossed on: 2034-06-08
#  • No DCL crossed on: 2033-09-28
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.39 years (141 days)
#  • DCL   crossed on: 2031-12-05
#  • No DCL crossed on: 2031-07-16
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.97 years (355 days)
#  • DCL   crossed on: 2031-11-11
#  • No DCL crossed on: 2030-11-20
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.04 years (12 days)
#  • DCL   crossed on: 2030-04-01
#  • No DCL crossed on: 2030-03-19
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 2.51 years (915 days)
#  • DCL   crossed on: 2033-07-20
#  • No DCL crossed on: 2031-01-16
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.21 years (75 days)
#  • DCL   crossed on: 2030-05-01
#  • No DCL crossed on: 2030-02-14
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.13 years (46 days)
#  • DCL   crossed on: 2030-09-25
#  • No DCL crossed on: 2030-08-09
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.17 years (61 days)
#  • DCL   crossed on: 2031-07-30
#  • No DCL crossed on: 2031-05-29
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.02 years (6 days)
#  • DCL   crossed on: 2030-02-25
#  • No DCL crossed on: 2030-02-18
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.91 years (330 days)
#  • DCL   crossed on: 2031-05-21
#  • No DCL crossed on: 2030-06-24
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.03 years (10 days)
#  • DCL   crossed on: 2030-12-23
#  • No DCL crossed on: 2030-12-12
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.23 years (83 days)
#  • DCL   crossed on: 2030-05-30
#  • No DCL crossed on: 2030-03-07
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.20 years (439 days)
#  • DCL   crossed on: 2032-11-24
#  • No DCL crossed on: 2031-09-11
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.09 years (33 days)
#  • DCL   crossed on: 2031-05-13
#  • No DCL crossed on: 2031-04-09
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.23 years (83 days)
#  • DCL   crossed on: 2034-06-20
#  • No DCL crossed on: 2034-03-28
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.36 years (132 days)
#  • DCL   crossed on: 2033-02-17
#  • No DCL crossed on: 2032-10-07
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.08 years (395 days)
#  • DCL   crossed on: 2032-05-07
#  • No DCL crossed on: 2031-04-07
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 2.64 years (962 days)
#  • DCL   crossed on: 2034-08-11
#  • No DCL crossed on: 2031-12-22
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 2.25 years (819 days)
#  • DCL   crossed on: 2033-03-02
#  • No DCL crossed on: 2030-12-03
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.30 years (473 days)
#  • DCL   crossed on: 2032-01-21
#  • No DCL crossed on: 2030-10-04
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 3.26 years (1188 days)
#  • DCL   crossed on: 2034-03-15
#  • No DCL crossed on: 2030-12-12
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.60 years (582 days)
#  • DCL   crossed on: 2030-07-19
#  • No DCL crossed on: 2028-12-13
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.76 years (275 days)
#  • DCL   crossed on: 2032-06-03
#  • No DCL crossed on: 2031-09-01
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.09 years (33 days)
#  • DCL   crossed on: 2028-08-16
#  • No DCL crossed on: 2028-07-13
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.96 years (349 days)
#  • DCL   crossed on: 2031-07-01
#  • No DCL crossed on: 2030-07-16
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.20 years (73 days)
#  • DCL   crossed on: 2029-02-05
#  • No DCL crossed on: 2028-11-23
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.23 years (83 days)
#  • DCL   crossed on: 2032-01-16
#  • No DCL crossed on: 2031-10-24
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.44 years (525 days)
#  • DCL   crossed on: 2033-12-23
#  • No DCL crossed on: 2032-07-15
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.89 years (325 days)
#  • DCL   crossed on: 2032-12-14
#  • No DCL crossed on: 2032-01-23
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.98 years (356 days)
#  • DCL   crossed on: 2031-10-17
#  • No DCL crossed on: 2030-10-25
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.02 years (7 days)
#  • DCL   crossed on: 2029-03-07
#  • No DCL crossed on: 2029-02-27
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.32 years (482 days)
#  • DCL   crossed on: 2031-10-14
#  • No DCL crossed on: 2030-06-18
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.86 years (678 days)
#  • DCL   crossed on: 2033-06-27
#  • No DCL crossed on: 2031-08-18
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.96 years (351 days)
#  • DCL   crossed on: 2029-09-14
#  • No DCL crossed on: 2028-09-27
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.13 years (46 days)
#  • DCL   crossed on: 2027-12-07
#  • No DCL crossed on: 2027-10-21
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.03 years (376 days)
#  • DCL   crossed on: 2031-07-24
#  • No DCL crossed on: 2030-07-12
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.18 years (63 days)
#  • DCL   crossed on: 2030-10-09
#  • No DCL crossed on: 2030-08-06
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.20 years (71 days)
#  • DCL   crossed on: 2031-02-05
#  • No DCL crossed on: 2030-11-25
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 3.20 years (1167 days)
#  • DCL   crossed on: 2033-05-31
#  • No DCL crossed on: 2030-03-20
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.95 years (710 days)
#  • DCL   crossed on: 2033-12-20
#  • No DCL crossed on: 2032-01-09
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.07 years (26 days)
#  • DCL   crossed on: 2032-07-26
#  • No DCL crossed on: 2032-06-29
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.68 years (613 days)
#  • DCL   crossed on: 2032-06-22
#  • No DCL crossed on: 2030-10-17
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.28 years (100 days)
#  • DCL   crossed on: 2032-01-22
#  • No DCL crossed on: 2031-10-13
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.47 years (171 days)
#  • DCL   crossed on: 2033-02-08
#  • No DCL crossed on: 2032-08-20
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.02 years (5 days)
#  • DCL   crossed on: 2027-09-16
#  • No DCL crossed on: 2027-09-10
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 2.24 years (816 days)
#  • DCL   crossed on: 2032-05-17
#  • No DCL crossed on: 2030-02-20
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.23 years (83 days)
#  • DCL   crossed on: 2032-04-23
#  • No DCL crossed on: 2032-01-30
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.18 years (65 days)
#  • DCL   crossed on: 2032-11-11
#  • No DCL crossed on: 2032-09-06
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.73 years (265 days)
#  • DCL   crossed on: 2029-07-24
#  • No DCL crossed on: 2028-10-31
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.09 years (33 days)
#  • DCL   crossed on: 2030-02-11
#  • No DCL crossed on: 2030-01-08
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.13 years (45 days)
#  • DCL   crossed on: 2032-02-27
#  • No DCL crossed on: 2032-01-12
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.49 years (545 days)
#  • DCL   crossed on: 2032-08-31
#  • No DCL crossed on: 2031-03-04
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.05 years (18 days)
#  • DCL   crossed on: 2030-09-10
#  • No DCL crossed on: 2030-08-22
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.70 years (620 days)
#  • DCL   crossed on: 2031-03-25
#  • No DCL crossed on: 2029-07-12
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.29 years (104 days)
#  • DCL   crossed on: 2032-05-21
#  • No DCL crossed on: 2032-02-06
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.65 years (603 days)
#  • DCL   crossed on: 2034-08-17
#  • No DCL crossed on: 2032-12-21
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.29 years (104 days)
#  • DCL   crossed on: 2030-06-14
#  • No DCL crossed on: 2030-03-01
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.76 years (642 days)
#  • DCL   crossed on: 2032-11-11
#  • No DCL crossed on: 2031-02-07
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.47 years (172 days)
#  • DCL   crossed on: 2033-08-17
#  • No DCL crossed on: 2033-02-25
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.44 years (525 days)
#  • DCL   crossed on: 2031-01-22
#  • No DCL crossed on: 2029-08-14
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.93 years (705 days)
#  • DCL   crossed on: 2034-05-09
#  • No DCL crossed on: 2032-06-02
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 4.42 years (1613 days)
#  • DCL   crossed on: 2034-04-19
#  • No DCL crossed on: 2029-11-16
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.11 years (41 days)
#  • DCL   crossed on: 2032-03-09
#  • No DCL crossed on: 2032-01-27
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.55 years (200 days)
#  • DCL   crossed on: 2031-08-11
#  • No DCL crossed on: 2031-01-22
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.08 years (27 days)
#  • DCL   crossed on: 2030-11-13
#  • No DCL crossed on: 2030-10-16
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.15 years (55 days)
#  • DCL   crossed on: 2031-01-24
#  • No DCL crossed on: 2030-11-29
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.38 years (138 days)
#  • DCL   crossed on: 2032-07-06
#  • No DCL crossed on: 2032-02-18
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.04 years (14 days)
#  • DCL   crossed on: 2029-07-19
#  • No DCL crossed on: 2029-07-04
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.01 years (2 days)
#  • DCL   crossed on: 2031-03-27
#  • No DCL crossed on: 2031-03-24
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.02 years (5 days)
#  • DCL   crossed on: 2028-04-12
#  • No DCL crossed on: 2028-04-06
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.02 years (7 days)
#  • DCL   crossed on: 2028-11-01
#  • No DCL crossed on: 2028-10-24
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.12 years (44 days)
#  • DCL   crossed on: 2029-08-16
#  • No DCL crossed on: 2029-07-02
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.14 years (415 days)
#  • DCL   crossed on: 2030-11-25
#  • No DCL crossed on: 2029-10-05
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.31 years (112 days)
#  • DCL   crossed on: 2031-06-12
#  • No DCL crossed on: 2031-02-19
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.07 years (24 days)
#  • DCL   crossed on: 2033-02-11
#  • No DCL crossed on: 2033-01-17
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.16 years (57 days)
#  • DCL   crossed on: 2031-05-29
#  • No DCL crossed on: 2031-04-01
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.51 years (184 days)
#  • DCL   crossed on: 2029-05-17
#  • No DCL crossed on: 2028-11-13
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 2.53 years (924 days)
#  • DCL   crossed on: 2032-06-04
#  • No DCL crossed on: 2029-11-22
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.36 years (130 days)
#  • DCL   crossed on: 2030-04-30
#  • No DCL crossed on: 2029-12-20
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.35 years (128 days)
#  • DCL   crossed on: 2028-10-13
#  • No DCL crossed on: 2028-06-06
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.02 years (5 days)
#  • DCL   crossed on: 2031-03-06
#  • No DCL crossed on: 2031-02-28
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.51 years (187 days)
#  • DCL   crossed on: 2032-01-22
#  • No DCL crossed on: 2031-07-18
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.23 years (82 days)
#  • DCL   crossed on: 2031-05-05
#  • No DCL crossed on: 2031-02-11
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.02 years (6 days)
#  • DCL   crossed on: 2028-10-13
#  • No DCL crossed on: 2028-10-06
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.21 years (75 days)
#  • DCL   crossed on: 2034-05-18
#  • No DCL crossed on: 2034-03-03
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.20 years (71 days)
#  • DCL   crossed on: 2029-12-12
#  • No DCL crossed on: 2029-10-01
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.29 years (104 days)
#  • DCL   crossed on: 2030-05-24
#  • No DCL crossed on: 2030-02-08
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.87 years (315 days)
#  • DCL   crossed on: 2033-11-16
#  • No DCL crossed on: 2033-01-04
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.11 years (39 days)
#  • DCL   crossed on: 2034-05-23
#  • No DCL crossed on: 2034-04-13
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.02 years (6 days)
#  • DCL   crossed on: 2033-06-27
#  • No DCL crossed on: 2033-06-20
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.03 years (11 days)
#  • DCL   crossed on: 2028-05-31
#  • No DCL crossed on: 2028-05-19
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.06 years (20 days)
#  • DCL   crossed on: 2028-08-14
#  • No DCL crossed on: 2028-07-24
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.30 years (474 days)
#  • DCL   crossed on: 2032-04-22
#  • No DCL crossed on: 2031-01-03
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.57 years (207 days)
#  • DCL   crossed on: 2032-06-15
#  • No DCL crossed on: 2031-11-20
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.07 years (23 days)
#  • DCL   crossed on: 2031-04-18
#  • No DCL crossed on: 2031-03-25
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.45 years (530 days)
#  • DCL   crossed on: 2034-03-06
#  • No DCL crossed on: 2032-09-21
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 2.15 years (783 days)
#  • DCL   crossed on: 2033-03-02
#  • No DCL crossed on: 2031-01-08
#
# --- Credit Suisse - No DCL ---
# ...
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.28 years (100 days)
#  • DCL   crossed on: 2028-11-03
#  • No DCL crossed on: 2028-07-25
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.70 years (253 days)
#  • DCL   crossed on: 2029-03-23
#  • No DCL crossed on: 2028-07-12
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.42 years (152 days)
#  • DCL   crossed on: 2032-08-03
#  • No DCL crossed on: 2032-03-03
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.06 years (22 days)
#  • DCL   crossed on: 2027-10-29
#  • No DCL crossed on: 2027-10-06
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.96 years (350 days)
#  • DCL   crossed on: 2034-05-17
#  • No DCL crossed on: 2033-05-31
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 2.40 years (875 days)
#  • DCL   crossed on: 2032-12-23
#  • No DCL crossed on: 2030-07-31
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.03 years (10 days)
#  • DCL   crossed on: 2029-07-17
#  • No DCL crossed on: 2029-07-06
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.94 years (341 days)
#  • DCL   crossed on: 2032-07-19
#  • No DCL crossed on: 2031-08-12
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 2.62 years (956 days)
#  • DCL   crossed on: 2034-03-01
#  • No DCL crossed on: 2031-07-18
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.42 years (152 days)
#  • DCL   crossed on: 2033-03-24
#  • No DCL crossed on: 2032-10-22
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.16 years (56 days)
#  • DCL   crossed on: 2029-09-05
#  • No DCL crossed on: 2029-07-10
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.17 years (425 days)
#  • DCL   crossed on: 2031-05-06
#  • No DCL crossed on: 2030-03-06
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.49 years (179 days)
#  • DCL   crossed on: 2030-07-03
#  • No DCL crossed on: 2030-01-04
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.08 years (30 days)
#  • DCL   crossed on: 2029-05-07
#  • No DCL crossed on: 2029-04-06
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.40 years (509 days)
#  • DCL   crossed on: 2033-10-04
#  • No DCL crossed on: 2032-05-12
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.23 years (84 days)
#  • DCL   crossed on: 2030-11-21
#  • No DCL crossed on: 2030-08-28
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.11 years (38 days)
#  • DCL   crossed on: 2029-09-10
#  • No DCL crossed on: 2029-08-02
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.42 years (152 days)
#  • DCL   crossed on: 2030-11-21
#  • No DCL crossed on: 2030-06-21
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.69 years (251 days)
#  • DCL   crossed on: 2034-07-06
#  • No DCL crossed on: 2033-10-27
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.04 years (13 days)
#  • DCL   crossed on: 2031-03-28
#  • No DCL crossed on: 2031-03-14
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.78 years (284 days)
#  • DCL   crossed on: 2029-10-16
#  • No DCL crossed on: 2029-01-04
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.28 years (100 days)
#  • DCL   crossed on: 2030-04-11
#  • No DCL crossed on: 2029-12-31
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.40 years (146 days)
#  • DCL   crossed on: 2032-10-25
#  • No DCL crossed on: 2032-05-31
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.36 years (131 days)
#  • DCL   crossed on: 2033-06-01
#  • No DCL crossed on: 2033-01-20
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.46 years (167 days)
#  • DCL   crossed on: 2032-10-13
#  • No DCL crossed on: 2032-04-28
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.02 years (7 days)
#  • DCL   crossed on: 2029-11-14
#  • No DCL crossed on: 2029-11-06
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.02 years (7 days)
#  • DCL   crossed on: 2030-06-07
#  • No DCL crossed on: 2030-05-30
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.22 years (78 days)
#  • DCL   crossed on: 2032-11-25
#  • No DCL crossed on: 2032-09-07
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.42 years (518 days)
#  • DCL   crossed on: 2031-10-30
#  • No DCL crossed on: 2030-05-29
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.11 years (41 days)
#  • DCL   crossed on: 2028-02-11
#  • No DCL crossed on: 2027-12-31
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.90 years (326 days)
#  • DCL   crossed on: 2032-07-27
#  • No DCL crossed on: 2031-09-04
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.72 years (628 days)
#  • DCL   crossed on: 2031-08-13
#  • No DCL crossed on: 2029-11-22
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.91 years (331 days)
#  • DCL   crossed on: 2030-05-17
#  • No DCL crossed on: 2029-06-19
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.13 years (48 days)
#  • DCL   crossed on: 2029-10-31
#  • No DCL crossed on: 2029-09-12
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.02 years (5 days)
#  • DCL   crossed on: 2031-04-01
#  • No DCL crossed on: 2031-03-26
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.02 years (6 days)
#  • DCL   crossed on: 2028-06-06
#  • No DCL crossed on: 2028-05-30
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.44 years (160 days)
#  • DCL   crossed on: 2032-12-06
#  • No DCL crossed on: 2032-06-28
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.38 years (504 days)
#  • DCL   crossed on: 2033-07-15
#  • No DCL crossed on: 2032-02-26
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 2.82 years (1030 days)
#  • DCL   crossed on: 2032-01-01
#  • No DCL crossed on: 2029-03-06
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 4.12 years (1502 days)
#  • DCL   crossed on: 2033-03-08
#  • No DCL crossed on: 2029-01-24
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.46 years (167 days)
#  • DCL   crossed on: 2030-11-06
#  • No DCL crossed on: 2030-05-22
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 2.65 years (967 days)
#  • DCL   crossed on: 2033-02-24
#  • No DCL crossed on: 2030-07-02
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.03 years (11 days)
#  • DCL   crossed on: 2029-11-19
#  • No DCL crossed on: 2029-11-07
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.80 years (293 days)
#  • DCL   crossed on: 2031-02-14
#  • No DCL crossed on: 2030-04-26
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.98 years (358 days)
#  • DCL   crossed on: 2033-06-09
#  • No DCL crossed on: 2032-06-15
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.25 years (89 days)
#  • DCL   crossed on: 2029-10-10
#  • No DCL crossed on: 2029-07-12
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.17 years (426 days)
#  • DCL   crossed on: 2034-08-08
#  • No DCL crossed on: 2033-06-07
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.01 years (3 days)
#  • DCL   crossed on: 2030-05-10
#  • No DCL crossed on: 2030-05-06
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.17 years (62 days)
#  • DCL   crossed on: 2031-02-18
#  • No DCL crossed on: 2030-12-17
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 2.01 years (734 days)
#  • DCL   crossed on: 2030-08-16
#  • No DCL crossed on: 2028-08-11
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.71 years (257 days)
#  • DCL   crossed on: 2028-06-28
#  • No DCL crossed on: 2027-10-14
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.60 years (582 days)
#  • DCL   crossed on: 2032-04-08
#  • No DCL crossed on: 2030-09-03
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.04 years (14 days)
#  • DCL   crossed on: 2028-12-06
#  • No DCL crossed on: 2028-11-21
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.42 years (517 days)
#  • DCL   crossed on: 2031-10-31
#  • No DCL crossed on: 2030-05-31
#
# --- Credit Suisse - No DCL ---
# ⚠️  Neither 'Monte Carlo - Bi-annual' nor 'Credit Suisse - No DCL' ever exceeded a leverage of 0.96.
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 1.58 years (575 days)
#  • DCL   crossed on: 2034-07-19
#  • No DCL crossed on: 2032-12-20
#
# --- Credit Suisse - No DCL ---
# Δ to reach 96.00%: 0.65 years (238 days)
#  • DCL   crossed on: 2034-02-23
#  • No DCL crossed on: 2033-06-29
# Mean delay   : 238.7 days
# Median delay : 132.5 days
# Std. dev.    : 285.9 days
# Range        : -20 to 2197 days
# Number of negative delays: 3

# %%
# Plot results for a monte carlo simulation with a negative delay

for dcl in monte_carlo_dcls:
    years_diff, dcl_date, no_dcl_date = get_delta_collapse(dcl[0], dcl[1], L_PONV=0.96)
    if years_diff is not None and years_diff < 0:
        print(f"Negative delay: {years_diff:.2f} years")
        delta_days = (dcl_date - no_dcl_date).days
        print(f"Δ to reach L_PONV: {years_diff:.2f} years ({delta_days} days)")
        print(f" • No DCL crossed on: {no_dcl_date.date()}")
        print(f" • DCL   crossed on: {dcl_date.date()}")
        plot_results(dcl[0], dcl[1], title="Monte Carlo - Negative Delay")
        break
# Out:
# Negative delay: -0.02 years
# Δ to reach L_PONV: -0.02 years (-8 days)
#  • No DCL crossed on: 2029-11-27
#  • DCL   crossed on: 2029-11-19

# %%
# Plot results for the longest delay
longest_delay = max(day_diffs)


for dcl in monte_carlo_dcls:
    years_diff, dcl_date, no_dcl_date = get_delta_collapse(dcl[0], dcl[1], L_PONV=0.96)
    if years_diff is not None:
        delta_days = (dcl_date - no_dcl_date).days
        if delta_days == longest_delay:
            print(f"Longest delay: {years_diff:.2f} years")
            print(f"Δ to reach L_PONV: {years_diff:.2f} years ({delta_days} days)")
            print(f" • No DCL crossed on: {no_dcl_date.date()}")
            print(f" • DCL   crossed on: {dcl_date.date()}")
            plot_results(dcl[0], dcl[1], title="Monte Carlo - Longest Delay")
            break
# Out:
# Longest delay: 6.02 years
# Δ to reach L_PONV: 6.02 years (2197 days)
#  • No DCL crossed on: 2028-06-21
#  • DCL   crossed on: 2034-06-27
